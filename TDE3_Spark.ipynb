# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielfjm/TDE3-SPARK/blob/main/TDE3_Spark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('tde3').getOrCreate()

sc = spark.sparkContext

# Carregar o dataset, remover o cabeçalho e tratar dados faltantes
url = '/content/drive/MyDrive/FACULDADE/operacoes_comerciais_inteira.csv'

rdd = sc.textFile(url)
rdd = rdd.filter(lambda line: "Country" not in line).filter(lambda line: line.strip() != "")

# %%
# 1 - Contar transações envolvendo o Brasil:
brazil_transactions = rdd.filter(lambda line: "Brazil" in line.split(";")[0]).count()
print(brazil_transactions)
# Out:
# 184748

# %%
# 2 - Número de transações envolvendo o Brasil com PairRDD:
brazil_pair_rdd = rdd.filter(lambda line: "Brazil" in line.split(";")[0]).map(lambda line: ("Brazil", 1)).reduceByKey(lambda x, y: x + y)
print(brazil_pair_rdd.collect())
# Out:
# [('Brazil', 184748)]

# %%
# 3 - Número de transações envolvendo o Brasil em 2016 com RDD:
brazil_2016 = rdd.filter(lambda line: "Brazil" in line.split(";")[0] and "2016" in line.split(";")[1]).count()
print(brazil_2016)
# Out:
# 6210

# %%
# 4 - Número de transações envolvendo o Brasil em 2016 com PairRDD:
brazil2016_pair_rdd = rdd.filter(lambda line: "Brazil" in line.split(";")[0] and "2016" in line.split(";")[1]).map(lambda line: ("Brazil", 1)).reduceByKey(lambda x, y: x + y)
print(brazil2016_pair_rdd.collect())
# Out:
# [('Brazil', 6210)]

# %%
# 5 - Transações por flow e ano a partir de 2010:
# Filtrar dados a partir de 2010, ignorando linhas com formato inesperado
rdd_filtered = rdd.filter(lambda line: len(line.split(";")) > 4 and line.split(";")[1].isdigit() and int(line.split(";")[1]) >= 2010)

# Transformar Flow em maiúsculas e mapear (ano, flow) como chave, com valor 1 para contagem
flow_year_rdd = rdd_filtered.map(lambda line: ((line.split(";")[1], line.split(";")[4].upper()), 1))

# Contar o número de transações por ano e flow
flow_year_count = flow_year_rdd.reduceByKey(lambda x, y: x + y)

# Ordenar por ano
flow_year_count_sorted = flow_year_count.sortByKey()

# Exibir o resultado
for record in flow_year_count_sorted.collect():
    print(record)
# Out:
# (('2010', 'EXPORT'), 125013)
# (('2010', 'IMPORT'), 222447)
# (('2010', 'RE-EXPORT'), 17058)
# (('2010', 'RE-IMPORT'), 9273)
# (('2011', 'EXPORT'), 125909)
# (('2011', 'IMPORT'), 220850)
# (('2011', 'RE-EXPORT'), 17564)
# (('2011', 'RE-IMPORT'), 10273)
# (('2012', 'EXPORT'), 128072)
# (('2012', 'IMPORT'), 222034)
# (('2012', 'RE-EXPORT'), 16900)
# (('2012', 'RE-IMPORT'), 10337)
# (('2013', 'EXPORT'), 127904)
# (('2013', 'IMPORT'), 216282)
# (('2013', 'RE-EXPORT'), 16758)
# (('2013', 'RE-IMPORT'), 9992)
# (('2014', 'EXPORT'), 125142)
# (('2014', 'IMPORT'), 208749)
# (('2014', 'RE-EXPORT'), 20139)
# (('2014', 'RE-IMPORT'), 10424)
# (('2015', 'EXPORT'), 125878)
# (('2015', 'IMPORT'), 203920)
# (('2015', 'RE-EXPORT'), 18966)
# (('2015', 'RE-IMPORT'), 10288)
# (('2016', 'EXPORT'), 106104)
# (('2016', 'IMPORT'), 160235)
# (('2016', 'RE-EXPORT'), 16147)
# (('2016', 'RE-IMPORT'), 7024)

# %%
# 6 - Média do Price em 2016 com RDD:
# Filtrar as linhas para o ano de 2016, ignorando linhas com dados faltantes
prices_2016_rdd = rdd.filter(lambda line: len(line.split(";")) > 5 and line.split(";")[1] == "2016")

# Extrair a coluna Price, convertendo para float
prices_2016 = prices_2016_rdd.map(lambda line: float(line.split(";")[5]))

# Calcular a média dos preços
total_price = prices_2016.sum()
count_price = prices_2016.count()
average_price_usd = total_price / count_price if count_price > 0 else 0

# Conversão de USD para BRL (taxa de conversão fixa para este exemplo)
conversion_rate = 5.0  # Exemplo: 1 USD = 5 BRL
average_price_brl = average_price_usd * conversion_rate

# Formatar o valor em reais
average_price_brl_formatted = f"R$ {average_price_brl:,.2f}"
print(average_price_brl_formatted)
# Out:
# R$ 689,923,030.98

# %%
# 7 - Média do Price em 2016 com PairRDD:
# Taxa de conversão de USD para BRL
conversion_rate = 5.0  # Exemplo: 1 USD = 5 BRL

# Filtrar dados para o ano de 2016 e garantir que a coluna Price é um valor numérico
price_2016_rdd = rdd.filter(lambda line: len(line.split(";")) > 5 and line.split(";")[1] == "2016" and line.split(";")[5].replace('.', '', 1).isdigit())

# Mapear para chave (2016) e valor (Price, 1) para facilitar a média
price_pair_rdd = price_2016_rdd.map(lambda line: ("2016", (float(line.split(";")[5]), 1)))

# Reduzir somando os valores de Price e as contagens
price_sum_count = price_pair_rdd.reduceByKey(lambda x, y: (x[0] + y[0], x[1] + y[1]))

# Calcular a média, aplicar a taxa de conversão e formatar em reais
price_avg = price_sum_count.mapValues(lambda x: f"R$ {(x[0] / x[1]) * conversion_rate:,.2f}")

# Exibir o resultado
for record in price_avg.collect():
    print(record)
# Out:
# ('2016', 'R$ 689,923,030.98')

# %%
# 8 - O preço máximo e mínimo por categoria e por ano, ordenado por país com PairRDD:
# Definir a taxa de conversão de USD para BRL
conversion_rate = 5.0  # Exemplo: 1 USD = 5 BRL

# Filtrar o RDD para garantir que o ano, categoria e price são válidos
filtered_rdd = rdd.filter(lambda line: len(line.split(";")) > 6 and line.split(";")[5].replace('.', '', 1).isdigit())

# Mapear para (chave, valor) onde chave = (ano, categoria em maiúsculas) e valor = (price)
# Extrair ano, categoria, e price e garantir que categoria esteja em letras maiúsculas
pair_rdd = filtered_rdd.map(lambda line: (
    (line.split(";")[1], line.split(";")[9].upper()),  # Chave: (ano, categoria em maiúsculas)
    float(line.split(";")[5])  # Valor: preço convertido para float
))

# Calcular o máximo e mínimo para cada (ano, categoria)
# Usar reduceByKey para encontrar o máximo e mínimo de cada chave
min_max_rdd = pair_rdd.combineByKey(
    lambda price: (price, price),  # Inicializar o par (max, min) com o primeiro preço
    lambda acc, price: (max(acc[0], price), min(acc[1], price)),  # Atualizar máximo e mínimo
    lambda acc1, acc2: (max(acc1[0], acc2[0]), min(acc1[1], acc2[1]))  # Combinar para o máximo e mínimo final
)

# Converter os preços de USD para BRL e formatar o resultado
min_max_rdd_brl = min_max_rdd.mapValues(lambda x: (f"R$ {x[0] * conversion_rate:,.2f}", f"R$ {x[1] * conversion_rate:,.2f}"))

# Exibir o resultado ordenado por ano e categoria
for record in min_max_rdd_brl.sortByKey().collect():
    print(record)
# Out:
# (('1988', '01_LIVE_ANIMALS'), ('R$ 904,041,860.00', 'R$ 545.00'))
# (('1988', '02_MEAT_AND_EDIBLE_MEAT_OFFAL'), ('R$ 7,479,678,285.00', 'R$ 115.00'))
# (('1988', '03_FISH_CRUSTACEANS_MOLLUSCS_AQUATIC_INVERTEBRATES_NE'), ('R$ 788,415,965.00', 'R$ 90.00'))
# (('1988', '04_DAIRY_PRODUCTS_EGGS_HONEY_EDIBLE_ANIMAL_PRODUCT_NES'), ('R$ 7,373,920,000.00', 'R$ 60.00'))
# (('1988', '05_PRODUCTS_OF_ANIMAL_ORIGIN_NES'), ('R$ 1,111,410,000.00', 'R$ 35.00'))
# (('1988', '06_LIVE_TREES_PLANTS_BULBS_ROOTS_CUT_FLOWERS_ETC'), ('R$ 4,336,074,880.00', 'R$ 125.00'))
# (('1988', '07_EDIBLE_VEGETABLES_AND_CERTAIN_ROOTS_AND_TUBERS'), ('R$ 2,216,529,920.00', 'R$ 230.00'))
# (('1988', '08_EDIBLE_FRUIT_NUTS_PEEL_OF_CITRUS_FRUIT_MELONS'), ('R$ 2,276,124,960.00', 'R$ 10.00'))
# (('1988', '09_COFFEE_TEA_MATE_AND_SPICES'), ('R$ 9,269,400,320.00', 'R$ 40.00'))
# (('1988', '10_CEREALS'), ('R$ 10,434,202,650.00', 'R$ 35.00'))
# (('1988', '11_MILLING_PRODUCTS_MALT_STARCHES_INULIN_WHEAT_GLUTE'), ('R$ 1,093,093,515.00', 'R$ 130.00'))
# (('1988', '12_OIL_SEED_OLEAGIC_FRUITS_GRAIN_SEED_FRUIT_ETC_NE'), ('R$ 7,138,045,120.00', 'R$ 125.00'))
# (('1988', '13_LAC_GUMS_RESINS_VEGETABLE_SAPS_AND_EXTRACTS_NES'), ('R$ 259,977,220.00', 'R$ 3,880.00'))
# (('1988', '14_VEGETABLE_PLAITING_MATERIALS_VEGETABLE_PRODUCTS_NES'), ('R$ 135,620,000.00', 'R$ 35.00'))
# (('1988', '15_ANIMAL_VEGETABLE_FATS_AND_OILS_CLEAVAGE_PRODUCTS_ET'), ('R$ 699,984,800.00', 'R$ 60.00'))
# (('1988', '16_MEAT_FISH_AND_SEAFOOD_FOOD_PREPARATIONS_NES'), ('R$ 2,354,874,460.00', 'R$ 100.00'))
# (('1988', '17_SUGARS_AND_SUGAR_CONFECTIONERY'), ('R$ 3,090,624,325.00', 'R$ 45.00'))
# (('1988', '18_COCOA_AND_COCOA_PREPARATIONS'), ('R$ 2,235,950,080.00', 'R$ 75.00'))
# (('1988', '19_CEREAL_FLOUR_STARCH_MILK_PREPARATIONS_AND_PRODUCTS'), ('R$ 1,379,464,960.00', 'R$ 1,085.00'))
# (('1988', '20_VEGETABLE_FRUIT_NUT_ETC_FOOD_PREPARATIONS'), ('R$ 1,682,430,080.00', 'R$ 40.00'))
# (('1988', '21_MISCELLANEOUS_EDIBLE_PREPARATIONS'), ('R$ 1,624,295,040.00', 'R$ 30.00'))
# (('1988', '22_BEVERAGES_SPIRITS_AND_VINEGAR'), ('R$ 3,053,384,960.00', 'R$ 10.00'))
# (('1988', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 2,470,540,000.00', 'R$ 175.00'))
# (('1988', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 3,746,780,530.00', 'R$ 285.00'))
# (('1988', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 705,968,560.00', 'R$ 115.00'))
# (('1988', '26_ORES_SLAG_AND_ASH'), ('R$ 12,335,840,360.00', 'R$ 25.00'))
# (('1988', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 92,116,504,850.00', 'R$ 255.00'))
# (('1988', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 7,087,299,450.00', 'R$ 80.00'))
# (('1988', '29_ORGANIC_CHEMICALS'), ('R$ 504,485,895.00', 'R$ 285.00'))
# (('1988', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 8,857,735,040.00', 'R$ 1,725.00'))
# (('1988', '31_FERTILIZERS'), ('R$ 1,376,855,040.00', 'R$ 40.00'))
# (('1988', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 5,210,070,080.00', 'R$ 1,475.00'))
# (('1988', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 1,024,624,960.00', 'R$ 75.00'))
# (('1988', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 1,949,555,040.00', 'R$ 2,095.00'))
# (('1988', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 711,795,040.00', 'R$ 605.00'))
# (('1988', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 131,880,000.00', 'R$ 300.00'))
# (('1988', '37_PHOTOGRAPHIC_OR_CINEMATOGRAPHIC_GOODS'), ('R$ 3,784,367,295.00', 'R$ 135.00'))
# (('1988', '38_MISCELLANEOUS_CHEMICAL_PRODUCTS'), ('R$ 6,989,120,000.00', 'R$ 480.00'))
# (('1988', '39_PLASTICS_AND_ARTICLES_THEREOF'), ('R$ 576,693,340.00', 'R$ 2,095.00'))
# (('1988', '40_RUBBER_AND_ARTICLES_THEREOF'), ('R$ 549,612,675.00', 'R$ 2,715.00'))
# (('1988', '41_RAW_HIDES_AND_SKINS_OTHER_THAN_FURSKINS_AND_LEATHER'), ('R$ 4,535,305,280.00', 'R$ 55.00'))
# (('1988', '42_ARTICLES_OF_LEATHER_ANIMAL_GUT_HARNESS_TRAVEL_GOOD'), ('R$ 3,901,714,880.00', 'R$ 755.00'))
# (('1988', '43_FURSKINS_AND_ARTIFICIAL_FUR_MANUFACTURES_THEREOF'), ('R$ 1,604,123,415.00', 'R$ 45.00'))
# (('1988', '44_WOOD_AND_ARTICLES_OF_WOOD_WOOD_CHARCOAL'), ('R$ 1,580,966,945.00', 'R$ 1,905.00'))
# (('1988', '45_CORK_AND_ARTICLES_OF_CORK'), ('R$ 1,108,096,560.00', 'R$ 225.00'))
# (('1988', '46_MANUFACTURES_OF_PLAITING_MATERIAL_BASKETWORK_ETC'), ('R$ 675,718,890.00', 'R$ 35.00'))
# (('1988', '47_PULP_OF_WOOD_FIBROUS_CELLULOSIC_MATERIAL_WASTE_ETC'), ('R$ 6,027,299,840.00', 'R$ 5.00'))
# (('1988', '48_PAPER_PAPERBOARD_ARTICLES_OF_PULP_PAPER_AND_BOARD'), ('R$ 766,687,540.00', 'R$ 2,270.00'))
# (('1988', '49_PRINTED_BOOKS_NEWSPAPERS_PICTURES_ETC'), ('R$ 3,601,255,040.00', 'R$ 30.00'))
# (('1988', '50_SILK'), ('R$ 1,493,112,180.00', 'R$ 375.00'))
# (('1988', '51_WOOL_ANIMAL_HAIR_HORSEHAIR_YARN_AND_FABRIC_THEREOF'), ('R$ 18,123,945,860.00', 'R$ 310.00'))
# (('1988', '52_COTTON'), ('R$ 1,554,237,035.00', 'R$ 35.00'))
# (('1988', '53_VEGETABLE_TEXTILE_FIBRES_NES_PAPER_YARN_WOVEN_FABRI'), ('R$ 439,605,080.00', 'R$ 20.00'))
# (('1988', '54_MANMADE_FILAMENTS'), ('R$ 2,300,689,920.00', 'R$ 125.00'))
# (('1988', '55_MANMADE_STAPLE_FIBRES'), ('R$ 415,726,375.00', 'R$ 350.00'))
# (('1988', '56_WADDING_FELT_NONWOVENS_YARNS_TWINE_CORDAGE_ETC'), ('R$ 2,671,780,000.00', 'R$ 765.00'))
# (('1988', '57_CARPETS_AND_OTHER_TEXTILE_FLOOR_COVERINGS'), ('R$ 3,262,744,960.00', 'R$ 320.00'))
# (('1988', '58_SPECIAL_WOVEN_OR_TUFTED_FABRIC_LACE_TAPESTRY_ETC'), ('R$ 429,975,000.00', 'R$ 105.00'))
# (('1988', '59_IMPREGNATED_COATED_OR_LAMINATED_TEXTILE_FABRIC'), ('R$ 675,580,000.00', 'R$ 260.00'))
# (('1988', '60_KNITTED_OR_CROCHETED_FABRIC'), ('R$ 811,570,000.00', 'R$ 845.00'))
# (('1988', '61_ARTICLES_OF_APPAREL_ACCESSORIES_KNIT_OR_CROCHET'), ('R$ 222,157,145.00', 'R$ 610.00'))
# (('1988', '62_ARTICLES_OF_APPAREL_ACCESSORIES_NOT_KNIT_OR_CROCHET'), ('R$ 130,953,240.00', 'R$ 1,950.00'))
# (('1988', '63_OTHER_MADE_TEXTILE_ARTICLES_SETS_WORN_CLOTHING_ETC'), ('R$ 183,562,310.00', 'R$ 2,435.00'))
# (('1988', '64_FOOTWEAR_GAITERS_AND_THE_LIKE_PARTS_THEREOF'), ('R$ 5,716,129,920.00', 'R$ 410.00'))
# (('1988', '65_HEADGEAR_AND_PARTS_THEREOF'), ('R$ 403,406,960.00', 'R$ 95.00'))
# (('1988', '66_UMBRELLAS_WALKING_STICKS_SEAT_STICKS_WHIPS_ETC'), ('R$ 467,206,415.00', 'R$ 635.00'))
# (('1988', '67_BIRD_SKIN_FEATHERS_ARTIFICIAL_FLOWERS_HUMAN_HAIR'), ('R$ 238,220,440.00', 'R$ 1,210.00'))
# (('1988', '68_STONE_PLASTER_CEMENT_ASBESTOS_MICA_ETC_ARTICLES'), ('R$ 768,535,040.00', 'R$ 130.00'))
# (('1988', '69_CERAMIC_PRODUCTS'), ('R$ 2,145,704,960.00', 'R$ 1,035.00'))
# (('1988', '70_GLASS_AND_GLASSWARE'), ('R$ 152,569,940.00', 'R$ 780.00'))
# (('1988', '71_PEARLS_PRECIOUS_STONES_METALS_COINS_ETC'), ('R$ 19,788,775,865.00', 'R$ 285.00'))
# (('1988', '72_IRON_AND_STEEL'), ('R$ 219,009,005.00', 'R$ 1,685.00'))
# (('1988', '73_ARTICLES_OF_IRON_OR_STEEL'), ('R$ 245,258,210.00', 'R$ 145.00'))
# (('1988', '74_COPPER_AND_ARTICLES_THEREOF'), ('R$ 3,351,775,040.00', 'R$ 705.00'))
# (('1988', '75_NICKEL_AND_ARTICLES_THEREOF'), ('R$ 2,843,605,120.00', 'R$ 40.00'))
# (('1988', '76_ALUMINIUM_AND_ARTICLES_THEREOF'), ('R$ 17,836,966,385.00', 'R$ 875.00'))
# (('1988', '78_LEAD_AND_ARTICLES_THEREOF'), ('R$ 985,241,345.00', 'R$ 145.00'))
# (('1988', '79_ZINC_AND_ARTICLES_THEREOF'), ('R$ 897,620,000.00', 'R$ 100.00'))
# (('1988', '80_TIN_AND_ARTICLES_THEREOF'), ('R$ 1,146,021,215.00', 'R$ 120.00'))
# (('1988', '81_OTHER_BASE_METALS_CERMETS_ARTICLES_THEREOF'), ('R$ 477,391,065.00', 'R$ 60.00'))
# (('1988', '82_TOOLS_IMPLEMENTS_CUTLERY_ETC_OF_BASE_METAL'), ('R$ 295,808,715.00', 'R$ 3,950.00'))
# (('1988', '83_MISCELLANEOUS_ARTICLES_OF_BASE_METAL'), ('R$ 1,527,895,040.00', 'R$ 865.00'))
# (('1988', '85_ELECTRICAL_ELECTRONIC_EQUIPMENT'), ('R$ 844,400,380.00', 'R$ 2,180.00'))
# (('1988', '86_RAILWAY_TRAMWAY_LOCOMOTIVES_ROLLING_STOCK_EQUIPMEN'), ('R$ 3,759,591,680.00', 'R$ 1,670.00'))
# (('1988', '87_VEHICLES_OTHER_THAN_RAILWAY_TRAMWAY'), ('R$ 4,669,756,600.00', 'R$ 1,390.00'))
# (('1988', '88_AIRCRAFT_SPACECRAFT_AND_PARTS_THEREOF'), ('R$ 18,337,935,360.00', 'R$ 1,185.00'))
# (('1988', '89_SHIPS_BOATS_AND_OTHER_FLOATING_STRUCTURES'), ('R$ 10,149,704,405.00', 'R$ 10.00'))
# (('1988', '90_OPTICAL_PHOTO_TECHNICAL_MEDICAL_ETC_APPARATUS'), ('R$ 591,489,970.00', 'R$ 2,005.00'))
# (('1988', '91_CLOCKS_AND_WATCHES_AND_PARTS_THEREOF'), ('R$ 1,347,809,920.00', 'R$ 60.00'))
# (('1988', '92_MUSICAL_INSTRUMENTS_PARTS_AND_ACCESSORIES'), ('R$ 3,961,011,950.00', 'R$ 660.00'))
# (('1988', '93_ARMS_AND_AMMUNITION_PARTS_AND_ACCESSORIES_THEREOF'), ('R$ 488,993,160.00', 'R$ 820.00'))
# (('1988', '94_FURNITURE_LIGHTING_SIGNS_PREFABRICATED_BUILDINGS'), ('R$ 4,498,085,120.00', 'R$ 755.00'))
# (('1988', '95_TOYS_GAMES_SPORTS_REQUISITES'), ('R$ 1,036,410,000.00', 'R$ 310.00'))
# (('1988', '96_MISCELLANEOUS_MANUFACTURED_ARTICLES'), ('R$ 542,760,000.00', 'R$ 45.00'))
# (('1988', '97_WORKS_OF_ART_COLLECTORS_PIECES_AND_ANTIQUES'), ('R$ 7,019,445,835.00', 'R$ 2,450.00'))
# (('1988', '99_COMMODITIES_NOT_SPECIFIED_ACCORDING_TO_KIND'), ('R$ 55,610,076,160.00', 'R$ 3,605,420.00'))
# (('1988', 'ALL_COMMODITIES'), ('R$ 1,615,980,565,000.00', 'R$ 286,408,640.00'))
# (('1989', '01_LIVE_ANIMALS'), ('R$ 1,398,225,200.00', 'R$ 5.00'))
# (('1989', '02_MEAT_AND_EDIBLE_MEAT_OFFAL'), ('R$ 7,229,210,615.00', 'R$ 40.00'))
# (('1989', '03_FISH_CRUSTACEANS_MOLLUSCS_AQUATIC_INVERTEBRATES_NE'), ('R$ 1,442,745,760.00', 'R$ 100.00'))
# (('1989', '04_DAIRY_PRODUCTS_EGGS_HONEY_EDIBLE_ANIMAL_PRODUCT_NES'), ('R$ 6,609,164,800.00', 'R$ 75.00'))
# (('1989', '05_PRODUCTS_OF_ANIMAL_ORIGIN_NES'), ('R$ 1,234,440,555.00', 'R$ 225.00'))
# (('1989', '06_LIVE_TREES_PLANTS_BULBS_ROOTS_CUT_FLOWERS_ETC'), ('R$ 4,149,114,880.00', 'R$ 30.00'))
# (('1989', '07_EDIBLE_VEGETABLES_AND_CERTAIN_ROOTS_AND_TUBERS'), ('R$ 1,983,304,960.00', 'R$ 20.00'))
# (('1989', '08_EDIBLE_FRUIT_NUTS_PEEL_OF_CITRUS_FRUIT_MELONS'), ('R$ 2,098,100,000.00', 'R$ 70.00'))
# (('1989', '09_COFFEE_TEA_MATE_AND_SPICES'), ('R$ 8,958,645,120.00', 'R$ 75.00'))
# (('1989', '10_CEREALS'), ('R$ 11,288,444,950.00', 'R$ 5.00'))
# (('1989', '11_MILLING_PRODUCTS_MALT_STARCHES_INULIN_WHEAT_GLUTE'), ('R$ 1,435,879,965.00', 'R$ 60.00'))
# (('1989', '12_OIL_SEED_OLEAGIC_FRUITS_GRAIN_SEED_FRUIT_ETC_NE'), ('R$ 6,733,086,835.00', 'R$ 30.00'))
# (('1989', '13_LAC_GUMS_RESINS_VEGETABLE_SAPS_AND_EXTRACTS_NES'), ('R$ 329,086,395.00', 'R$ 70.00'))
# (('1989', '14_VEGETABLE_PLAITING_MATERIALS_VEGETABLE_PRODUCTS_NES'), ('R$ 262,019,520.00', 'R$ 95.00'))
# (('1989', '15_ANIMAL_VEGETABLE_FATS_AND_OILS_CLEAVAGE_PRODUCTS_ET'), ('R$ 1,506,709,120.00', 'R$ 10.00'))
# (('1989', '16_MEAT_FISH_AND_SEAFOOD_FOOD_PREPARATIONS_NES'), ('R$ 2,301,783,500.00', 'R$ 5.00'))
# (('1989', '17_SUGARS_AND_SUGAR_CONFECTIONERY'), ('R$ 4,130,797,770.00', 'R$ 15.00'))
# (('1989', '18_COCOA_AND_COCOA_PREPARATIONS'), ('R$ 1,866,704,960.00', 'R$ 50.00'))
# (('1989', '19_CEREAL_FLOUR_STARCH_MILK_PREPARATIONS_AND_PRODUCTS'), ('R$ 1,520,875,040.00', 'R$ 50.00'))
# (('1989', '20_VEGETABLE_FRUIT_NUT_ETC_FOOD_PREPARATIONS'), ('R$ 5,093,671,680.00', 'R$ 20.00'))
# (('1989', '21_MISCELLANEOUS_EDIBLE_PREPARATIONS'), ('R$ 1,696,880,000.00', 'R$ 75.00'))
# (('1989', '22_BEVERAGES_SPIRITS_AND_VINEGAR'), ('R$ 3,022,569,920.00', 'R$ 30.00'))
# (('1989', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 10,736,304,640.00', 'R$ 30.00'))
# (('1989', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 4,723,464,805.00', 'R$ 60.00'))
# (('1989', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 2,518,235,770.00', 'R$ 40.00'))
# (('1989', '26_ORES_SLAG_AND_ASH'), ('R$ 13,443,308,470.00', 'R$ 55.00'))
# (('1989', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 105,624,585,220.00', 'R$ 15.00'))
# (('1989', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 10,509,029,530.00', 'R$ 25.00'))
# (('1989', '29_ORGANIC_CHEMICALS'), ('R$ 254,412,340.00', 'R$ 30.00'))
# (('1989', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 9,232,110,080.00', 'R$ 45.00'))
# (('1989', '31_FERTILIZERS'), ('R$ 5,023,733,950.00', 'R$ 5.00'))
# (('1989', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 5,438,469,760.00', 'R$ 205.00'))
# (('1989', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 1,124,640,000.00', 'R$ 35.00'))
# (('1989', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 1,558,504,960.00', 'R$ 45.00'))
# (('1989', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 1,105,098,080.00', 'R$ 100.00'))
# (('1989', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 147,681,665.00', 'R$ 80.00'))
# (('1989', '37_PHOTOGRAPHIC_OR_CINEMATOGRAPHIC_GOODS'), ('R$ 4,019,768,075.00', 'R$ 100.00'))
# (('1989', '38_MISCELLANEOUS_CHEMICAL_PRODUCTS'), ('R$ 7,372,709,760.00', 'R$ 50.00'))
# (('1989', '39_PLASTICS_AND_ARTICLES_THEREOF'), ('R$ 655,503,770.00', 'R$ 155.00'))
# (('1989', '40_RUBBER_AND_ARTICLES_THEREOF'), ('R$ 1,486,021,395.00', 'R$ 100.00'))
# (('1989', '41_RAW_HIDES_AND_SKINS_OTHER_THAN_FURSKINS_AND_LEATHER'), ('R$ 4,715,166,400.00', 'R$ 50.00'))
# (('1989', '42_ARTICLES_OF_LEATHER_ANIMAL_GUT_HARNESS_TRAVEL_GOOD'), ('R$ 4,572,095,430.00', 'R$ 30.00'))
# (('1989', '43_FURSKINS_AND_ARTIFICIAL_FUR_MANUFACTURES_THEREOF'), ('R$ 1,792,301,275.00', 'R$ 50.00'))
# (('1989', '44_WOOD_AND_ARTICLES_OF_WOOD_WOOD_CHARCOAL'), ('R$ 22,724,813,900.00', 'R$ 30.00'))
# (('1989', '45_CORK_AND_ARTICLES_OF_CORK'), ('R$ 1,267,851,840.00', 'R$ 170.00'))
# (('1989', '46_MANUFACTURES_OF_PLAITING_MATERIAL_BASKETWORK_ETC'), ('R$ 464,001,225.00', 'R$ 30.00'))
# (('1989', '47_PULP_OF_WOOD_FIBROUS_CELLULOSIC_MATERIAL_WASTE_ETC'), ('R$ 21,866,485,450.00', 'R$ 95.00'))
# (('1989', '48_PAPER_PAPERBOARD_ARTICLES_OF_PULP_PAPER_AND_BOARD'), ('R$ 23,956,639,760.00', 'R$ 45.00'))
# (('1989', '49_PRINTED_BOOKS_NEWSPAPERS_PICTURES_ETC'), ('R$ 3,822,499,840.00', 'R$ 55.00'))
# (('1989', '50_SILK'), ('R$ 1,789,956,870.00', 'R$ 5.00'))
# (('1989', '51_WOOL_ANIMAL_HAIR_HORSEHAIR_YARN_AND_FABRIC_THEREOF'), ('R$ 16,044,465,930.00', 'R$ 40.00'))
# (('1989', '52_COTTON'), ('R$ 1,989,968,590.00', 'R$ 25.00'))
# (('1989', '53_VEGETABLE_TEXTILE_FIBRES_NES_PAPER_YARN_WOVEN_FABRI'), ('R$ 492,769,800.00', 'R$ 10.00'))
# (('1989', '54_MANMADE_FILAMENTS'), ('R$ 2,194,590,080.00', 'R$ 780.00'))
# (('1989', '55_MANMADE_STAPLE_FIBRES'), ('R$ 413,337,850.00', 'R$ 25.00'))
# (('1989', '56_WADDING_FELT_NONWOVENS_YARNS_TWINE_CORDAGE_ETC'), ('R$ 2,751,375,040.00', 'R$ 20.00'))
# (('1989', '57_CARPETS_AND_OTHER_TEXTILE_FLOOR_COVERINGS'), ('R$ 3,365,980,160.00', 'R$ 125.00'))
# (('1989', '58_SPECIAL_WOVEN_OR_TUFTED_FABRIC_LACE_TAPESTRY_ETC'), ('R$ 404,935,000.00', 'R$ 95.00'))
# (('1989', '59_IMPREGNATED_COATED_OR_LAMINATED_TEXTILE_FABRIC'), ('R$ 744,364,960.00', 'R$ 5.00'))
# (('1989', '60_KNITTED_OR_CROCHETED_FABRIC'), ('R$ 834,184,960.00', 'R$ 120.00'))
# (('1989', '61_ARTICLES_OF_APPAREL_ACCESSORIES_KNIT_OR_CROCHET'), ('R$ 249,657,300.00', 'R$ 15.00'))
# (('1989', '62_ARTICLES_OF_APPAREL_ACCESSORIES_NOT_KNIT_OR_CROCHET'), ('R$ 520,039,015.00', 'R$ 40.00'))
# (('1989', '63_OTHER_MADE_TEXTILE_ARTICLES_SETS_WORN_CLOTHING_ETC'), ('R$ 728,873,395.00', 'R$ 300.00'))
# (('1989', '64_FOOTWEAR_GAITERS_AND_THE_LIKE_PARTS_THEREOF'), ('R$ 6,314,524,800.00', 'R$ 95.00'))
# (('1989', '65_HEADGEAR_AND_PARTS_THEREOF'), ('R$ 462,919,080.00', 'R$ 25.00'))
# (('1989', '66_UMBRELLAS_WALKING_STICKS_SEAT_STICKS_WHIPS_ETC'), ('R$ 774,289,240.00', 'R$ 50.00'))
# (('1989', '67_BIRD_SKIN_FEATHERS_ARTIFICIAL_FLOWERS_HUMAN_HAIR'), ('R$ 549,572,285.00', 'R$ 90.00'))
# (('1989', '68_STONE_PLASTER_CEMENT_ASBESTOS_MICA_ETC_ARTICLES'), ('R$ 810,780,000.00', 'R$ 330.00'))
# (('1989', '69_CERAMIC_PRODUCTS'), ('R$ 2,349,164,960.00', 'R$ 15.00'))
# (('1989', '70_GLASS_AND_GLASSWARE'), ('R$ 742,700,625.00', 'R$ 160.00'))
# (('1989', '71_PEARLS_PRECIOUS_STONES_METALS_COINS_ETC'), ('R$ 16,627,353,120.00', 'R$ 40.00'))
# (('1989', '72_IRON_AND_STEEL'), ('R$ 3,816,445,120.00', 'R$ 25.00'))
# (('1989', '73_ARTICLES_OF_IRON_OR_STEEL'), ('R$ 331,581,900.00', 'R$ 445.00'))
# (('1989', '74_COPPER_AND_ARTICLES_THEREOF'), ('R$ 4,410,453,805.00', 'R$ 200.00'))
# (('1989', '75_NICKEL_AND_ARTICLES_THEREOF'), ('R$ 3,646,775,040.00', 'R$ 35.00'))
# (('1989', '76_ALUMINIUM_AND_ARTICLES_THEREOF'), ('R$ 17,586,806,245.00', 'R$ 5.00'))
# (('1989', '78_LEAD_AND_ARTICLES_THEREOF'), ('R$ 699,964,385.00', 'R$ 115.00'))
# (('1989', '79_ZINC_AND_ARTICLES_THEREOF'), ('R$ 2,894,166,880.00', 'R$ 25.00'))
# (('1989', '80_TIN_AND_ARTICLES_THEREOF'), ('R$ 2,143,776,890.00', 'R$ 75.00'))
# (('1989', '81_OTHER_BASE_METALS_CERMETS_ARTICLES_THEREOF'), ('R$ 557,905,075.00', 'R$ 15.00'))
# (('1989', '82_TOOLS_IMPLEMENTS_CUTLERY_ETC_OF_BASE_METAL'), ('R$ 464,955,390.00', 'R$ 375.00'))
# (('1989', '83_MISCELLANEOUS_ARTICLES_OF_BASE_METAL'), ('R$ 1,559,230,080.00', 'R$ 30.00'))
# (('1989', '85_ELECTRICAL_ELECTRONIC_EQUIPMENT'), ('R$ 1,012,260,200.00', 'R$ 2,270.00'))
# (('1989', '86_RAILWAY_TRAMWAY_LOCOMOTIVES_ROLLING_STOCK_EQUIPMEN'), ('R$ 5,214,243,840.00', 'R$ 220.00'))
# (('1989', '87_VEHICLES_OTHER_THAN_RAILWAY_TRAMWAY'), ('R$ 32,956,648,925.00', 'R$ 840.00'))
# (('1989', '88_AIRCRAFT_SPACECRAFT_AND_PARTS_THEREOF'), ('R$ 28,774,804,480.00', 'R$ 550.00'))
# (('1989', '89_SHIPS_BOATS_AND_OTHER_FLOATING_STRUCTURES'), ('R$ 12,073,748,130.00', 'R$ 610.00'))
# (('1989', '90_OPTICAL_PHOTO_TECHNICAL_MEDICAL_ETC_APPARATUS'), ('R$ 669,033,895.00', 'R$ 245.00'))
# (('1989', '91_CLOCKS_AND_WATCHES_AND_PARTS_THEREOF'), ('R$ 1,437,590,080.00', 'R$ 90.00'))
# (('1989', '92_MUSICAL_INSTRUMENTS_PARTS_AND_ACCESSORIES'), ('R$ 3,159,852,235.00', 'R$ 30.00'))
# (('1989', '93_ARMS_AND_AMMUNITION_PARTS_AND_ACCESSORIES_THEREOF'), ('R$ 621,409,375.00', 'R$ 135.00'))
# (('1989', '94_FURNITURE_LIGHTING_SIGNS_PREFABRICATED_BUILDINGS'), ('R$ 4,816,860,160.00', 'R$ 145.00'))
# (('1989', '95_TOYS_GAMES_SPORTS_REQUISITES'), ('R$ 1,241,304,960.00', 'R$ 10.00'))
# (('1989', '96_MISCELLANEOUS_MANUFACTURED_ARTICLES'), ('R$ 572,670,000.00', 'R$ 35.00'))
# (('1989', '97_WORKS_OF_ART_COLLECTORS_PIECES_AND_ANTIQUES'), ('R$ 10,224,728,900.00', 'R$ 15.00'))
# (('1989', '99_COMMODITIES_NOT_SPECIFIED_ACCORDING_TO_KIND'), ('R$ 56,056,325,120.00', 'R$ 619,585.00'))
# (('1989', 'ALL_COMMODITIES'), ('R$ 1,705,494,165,000.00', 'R$ 170,237,400.00'))
# (('1990', '01_LIVE_ANIMALS'), ('R$ 2,819,363,665.00', 'R$ 95.00'))
# (('1990', '02_MEAT_AND_EDIBLE_MEAT_OFFAL'), ('R$ 7,314,192,080.00', 'R$ 50.00'))
# (('1990', '03_FISH_CRUSTACEANS_MOLLUSCS_AQUATIC_INVERTEBRATES_NE'), ('R$ 2,449,858,470.00', 'R$ 40.00'))
# (('1990', '04_DAIRY_PRODUCTS_EGGS_HONEY_EDIBLE_ANIMAL_PRODUCT_NES'), ('R$ 8,374,995,200.00', 'R$ 30.00'))
# (('1990', '05_PRODUCTS_OF_ANIMAL_ORIGIN_NES'), ('R$ 1,335,435,040.00', 'R$ 5.00'))
# (('1990', '06_LIVE_TREES_PLANTS_BULBS_ROOTS_CUT_FLOWERS_ETC'), ('R$ 5,159,640,000.00', 'R$ 50.00'))
# (('1990', '07_EDIBLE_VEGETABLES_AND_CERTAIN_ROOTS_AND_TUBERS'), ('R$ 2,549,775,040.00', 'R$ 15.00'))
# (('1990', '08_EDIBLE_FRUIT_NUTS_PEEL_OF_CITRUS_FRUIT_MELONS'), ('R$ 3,628,310,080.00', 'R$ 25.00'))
# (('1990', '09_COFFEE_TEA_MATE_AND_SPICES'), ('R$ 6,909,185,280.00', 'R$ 15.00'))
# (('1990', '10_CEREALS'), ('R$ 12,206,449,160.00', 'R$ 5.00'))
# (('1990', '11_MILLING_PRODUCTS_MALT_STARCHES_INULIN_WHEAT_GLUTE'), ('R$ 1,679,898,800.00', 'R$ 25.00'))
# (('1990', '12_OIL_SEED_OLEAGIC_FRUITS_GRAIN_SEED_FRUIT_ETC_NE'), ('R$ 6,347,696,120.00', 'R$ 40.00'))
# (('1990', '13_LAC_GUMS_RESINS_VEGETABLE_SAPS_AND_EXTRACTS_NES'), ('R$ 491,174,070.00', 'R$ 45.00'))
# (('1990', '14_VEGETABLE_PLAITING_MATERIALS_VEGETABLE_PRODUCTS_NES'), ('R$ 206,572,160.00', 'R$ 10.00'))
# (('1990', '15_ANIMAL_VEGETABLE_FATS_AND_OILS_CLEAVAGE_PRODUCTS_ET'), ('R$ 1,606,839,680.00', 'R$ 30.00'))
# (('1990', '16_MEAT_FISH_AND_SEAFOOD_FOOD_PREPARATIONS_NES'), ('R$ 2,268,366,870.00', 'R$ 15.00'))
# (('1990', '17_SUGARS_AND_SUGAR_CONFECTIONERY'), ('R$ 4,048,862,950.00', 'R$ 15.00'))
# (('1990', '18_COCOA_AND_COCOA_PREPARATIONS'), ('R$ 2,130,064,960.00', 'R$ 65.00'))
# (('1990', '19_CEREAL_FLOUR_STARCH_MILK_PREPARATIONS_AND_PRODUCTS'), ('R$ 2,161,640,000.00', 'R$ 10.00'))
# (('1990', '20_VEGETABLE_FRUIT_NUT_ETC_FOOD_PREPARATIONS'), ('R$ 7,342,435,840.00', 'R$ 10.00'))
# (('1990', '21_MISCELLANEOUS_EDIBLE_PREPARATIONS'), ('R$ 2,262,275,040.00', 'R$ 5.00'))
# (('1990', '22_BEVERAGES_SPIRITS_AND_VINEGAR'), ('R$ 4,012,720,000.00', 'R$ 15.00'))
# (('1990', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 8,052,248,960.00', 'R$ 35.00'))
# (('1990', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 5,169,115,285.00', 'R$ 30.00'))
# (('1990', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 2,701,710,640.00', 'R$ 15.00'))
# (('1990', '26_ORES_SLAG_AND_ASH'), ('R$ 14,328,611,450.00', 'R$ 10.00'))
# (('1990', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 152,093,720,590.00', 'R$ 10.00'))
# (('1990', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 11,248,980,685.00', 'R$ 10.00'))
# (('1990', '29_ORGANIC_CHEMICALS'), ('R$ 220,066,910.00', 'R$ 55.00'))
# (('1990', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 11,438,609,920.00', 'R$ 40.00'))
# (('1990', '31_FERTILIZERS'), ('R$ 5,424,073,405.00', 'R$ 5.00'))
# (('1990', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 6,216,540,160.00', 'R$ 150.00'))
# (('1990', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 1,449,564,960.00', 'R$ 10.00'))
# (('1990', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 1,866,935,040.00', 'R$ 30.00'))
# (('1990', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 1,293,142,080.00', 'R$ 20.00'))
# (('1990', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 181,205,000.00', 'R$ 65.00'))
# (('1990', '37_PHOTOGRAPHIC_OR_CINEMATOGRAPHIC_GOODS'), ('R$ 4,176,427,990.00', 'R$ 115.00'))
# (('1990', '38_MISCELLANEOUS_CHEMICAL_PRODUCTS'), ('R$ 8,973,089,920.00', 'R$ 75.00'))
# (('1990', '39_PLASTICS_AND_ARTICLES_THEREOF'), ('R$ 653,152,585.00', 'R$ 5.00'))
# (('1990', '40_RUBBER_AND_ARTICLES_THEREOF'), ('R$ 2,026,048,835.00', 'R$ 35.00'))
# (('1990', '41_RAW_HIDES_AND_SKINS_OTHER_THAN_FURSKINS_AND_LEATHER'), ('R$ 5,281,966,720.00', 'R$ 20.00'))
# (('1990', '42_ARTICLES_OF_LEATHER_ANIMAL_GUT_HARNESS_TRAVEL_GOOD'), ('R$ 4,618,950,080.00', 'R$ 25.00'))
# (('1990', '43_FURSKINS_AND_ARTIFICIAL_FUR_MANUFACTURES_THEREOF'), ('R$ 1,726,025,685.00', 'R$ 20.00'))
# (('1990', '44_WOOD_AND_ARTICLES_OF_WOOD_WOOD_CHARCOAL'), ('R$ 22,451,981,435.00', 'R$ 100.00'))
# (('1990', '45_CORK_AND_ARTICLES_OF_CORK'), ('R$ 1,563,180,640.00', 'R$ 45.00'))
# (('1990', '46_MANUFACTURES_OF_PLAITING_MATERIAL_BASKETWORK_ETC'), ('R$ 383,699,990.00', 'R$ 25.00'))
# (('1990', '47_PULP_OF_WOOD_FIBROUS_CELLULOSIC_MATERIAL_WASTE_ETC'), ('R$ 19,500,825,525.00', 'R$ 65.00'))
# (('1990', '48_PAPER_PAPERBOARD_ARTICLES_OF_PULP_PAPER_AND_BOARD'), ('R$ 25,219,589,390.00', 'R$ 30.00'))
# (('1990', '49_PRINTED_BOOKS_NEWSPAPERS_PICTURES_ETC'), ('R$ 4,002,780,160.00', 'R$ 90.00'))
# (('1990', '50_SILK'), ('R$ 1,657,194,180.00', 'R$ 30.00'))
# (('1990', '51_WOOL_ANIMAL_HAIR_HORSEHAIR_YARN_AND_FABRIC_THEREOF'), ('R$ 9,649,218,310.00', 'R$ 30.00'))
# (('1990', '52_COTTON'), ('R$ 2,492,799,925.00', 'R$ 90.00'))
# (('1990', '53_VEGETABLE_TEXTILE_FIBRES_NES_PAPER_YARN_WOVEN_FABRI'), ('R$ 805,688,555.00', 'R$ 15.00'))
# (('1990', '54_MANMADE_FILAMENTS'), ('R$ 2,518,310,080.00', 'R$ 5.00'))
# (('1990', '55_MANMADE_STAPLE_FIBRES'), ('R$ 347,871,915.00', 'R$ 65.00'))
# (('1990', '56_WADDING_FELT_NONWOVENS_YARNS_TWINE_CORDAGE_ETC'), ('R$ 3,108,695,040.00', 'R$ 5.00'))
# (('1990', '57_CARPETS_AND_OTHER_TEXTILE_FLOOR_COVERINGS'), ('R$ 3,444,674,880.00', 'R$ 15.00'))
# (('1990', '58_SPECIAL_WOVEN_OR_TUFTED_FABRIC_LACE_TAPESTRY_ETC'), ('R$ 594,187,680.00', 'R$ 20.00'))
# (('1990', '59_IMPREGNATED_COATED_OR_LAMINATED_TEXTILE_FABRIC'), ('R$ 951,070,000.00', 'R$ 10.00'))
# (('1990', '60_KNITTED_OR_CROCHETED_FABRIC'), ('R$ 1,124,660,000.00', 'R$ 100.00'))
# (('1990', '61_ARTICLES_OF_APPAREL_ACCESSORIES_KNIT_OR_CROCHET'), ('R$ 309,902,740.00', 'R$ 10.00'))
# (('1990', '62_ARTICLES_OF_APPAREL_ACCESSORIES_NOT_KNIT_OR_CROCHET'), ('R$ 607,391,030.00', 'R$ 5.00'))
# (('1990', '63_OTHER_MADE_TEXTILE_ARTICLES_SETS_WORN_CLOTHING_ETC'), ('R$ 568,079,075.00', 'R$ 25.00'))
# (('1990', '64_FOOTWEAR_GAITERS_AND_THE_LIKE_PARTS_THEREOF'), ('R$ 8,108,645,120.00', 'R$ 30.00'))
# (('1990', '65_HEADGEAR_AND_PARTS_THEREOF'), ('R$ 520,269,200.00', 'R$ 50.00'))
# (('1990', '66_UMBRELLAS_WALKING_STICKS_SEAT_STICKS_WHIPS_ETC'), ('R$ 722,089,765.00', 'R$ 50.00'))
# (('1990', '67_BIRD_SKIN_FEATHERS_ARTIFICIAL_FLOWERS_HUMAN_HAIR'), ('R$ 469,545,745.00', 'R$ 10.00'))
# (('1990', '68_STONE_PLASTER_CEMENT_ASBESTOS_MICA_ETC_ARTICLES'), ('R$ 1,037,160,000.00', 'R$ 30.00'))
# (('1990', '69_CERAMIC_PRODUCTS'), ('R$ 3,275,714,880.00', 'R$ 5.00'))
# (('1990', '70_GLASS_AND_GLASSWARE'), ('R$ 710,839,625.00', 'R$ 15.00'))
# (('1990', '71_PEARLS_PRECIOUS_STONES_METALS_COINS_ETC'), ('R$ 17,006,278,220.00', 'R$ 20.00'))
# (('1990', '72_IRON_AND_STEEL'), ('R$ 2,138,342,400.00', 'R$ 135.00'))
# (('1990', '73_ARTICLES_OF_IRON_OR_STEEL'), ('R$ 345,112,810.00', 'R$ 10.00'))
# (('1990', '74_COPPER_AND_ARTICLES_THEREOF'), ('R$ 13,625,624,320.00', 'R$ 75.00'))
# (('1990', '75_NICKEL_AND_ARTICLES_THEREOF'), ('R$ 2,787,258,310.00', 'R$ 40.00'))
# (('1990', '76_ALUMINIUM_AND_ARTICLES_THEREOF'), ('R$ 16,954,527,220.00', 'R$ 15.00'))
# (('1990', '78_LEAD_AND_ARTICLES_THEREOF'), ('R$ 793,465,830.00', 'R$ 15.00'))
# (('1990', '79_ZINC_AND_ARTICLES_THEREOF'), ('R$ 1,823,548,445.00', 'R$ 10.00'))
# (('1990', '80_TIN_AND_ARTICLES_THEREOF'), ('R$ 1,668,159,835.00', 'R$ 15.00'))
# (('1990', '81_OTHER_BASE_METALS_CERMETS_ARTICLES_THEREOF'), ('R$ 616,237,685.00', 'R$ 5.00'))
# (('1990', '82_TOOLS_IMPLEMENTS_CUTLERY_ETC_OF_BASE_METAL'), ('R$ 277,451,875.00', 'R$ 5.00'))
# (('1990', '83_MISCELLANEOUS_ARTICLES_OF_BASE_METAL'), ('R$ 1,978,795,040.00', 'R$ 25.00'))
# (('1990', '85_ELECTRICAL_ELECTRONIC_EQUIPMENT'), ('R$ 1,007,293,170.00', 'R$ 3,890.00'))
# (('1990', '86_RAILWAY_TRAMWAY_LOCOMOTIVES_ROLLING_STOCK_EQUIPMEN'), ('R$ 5,125,676,480.00', 'R$ 190.00'))
# (('1990', '87_VEHICLES_OTHER_THAN_RAILWAY_TRAMWAY'), ('R$ 43,001,972,570.00', 'R$ 440.00'))
# (('1990', '88_AIRCRAFT_SPACECRAFT_AND_PARTS_THEREOF'), ('R$ 32,623,733,760.00', 'R$ 15.00'))
# (('1990', '89_SHIPS_BOATS_AND_OTHER_FLOATING_STRUCTURES'), ('R$ 13,003,536,250.00', 'R$ 275.00'))
# (('1990', '90_OPTICAL_PHOTO_TECHNICAL_MEDICAL_ETC_APPARATUS'), ('R$ 574,460,665.00', 'R$ 2,180.00'))
# (('1990', '91_CLOCKS_AND_WATCHES_AND_PARTS_THEREOF'), ('R$ 1,759,700,000.00', 'R$ 5.00'))
# (('1990', '92_MUSICAL_INSTRUMENTS_PARTS_AND_ACCESSORIES'), ('R$ 3,083,932,750.00', 'R$ 70.00'))
# (('1990', '93_ARMS_AND_AMMUNITION_PARTS_AND_ACCESSORIES_THEREOF'), ('R$ 717,772,960.00', 'R$ 10.00'))
# (('1990', '94_FURNITURE_LIGHTING_SIGNS_PREFABRICATED_BUILDINGS'), ('R$ 6,145,624,960.00', 'R$ 40.00'))
# (('1990', '95_TOYS_GAMES_SPORTS_REQUISITES'), ('R$ 1,716,384,960.00', 'R$ 15.00'))
# (('1990', '96_MISCELLANEOUS_MANUFACTURED_ARTICLES'), ('R$ 719,610,000.00', 'R$ 15.00'))
# (('1990', '97_WORKS_OF_ART_COLLECTORS_PIECES_AND_ANTIQUES'), ('R$ 17,327,835,110.00', 'R$ 10.00'))
# (('1990', '99_COMMODITIES_NOT_SPECIFIED_ACCORDING_TO_KIND'), ('R$ 70,744,437,760.00', 'R$ 742,740.00'))
# (('1990', 'ALL_COMMODITIES'), ('R$ 1,991,905,875,000.00', 'R$ 46,766,385.00'))
# (('1991', '01_LIVE_ANIMALS'), ('R$ 4,810,072,330.00', 'R$ 5.00'))
# (('1991', '02_MEAT_AND_EDIBLE_MEAT_OFFAL'), ('R$ 8,145,709,085.00', 'R$ 25.00'))
# (('1991', '03_FISH_CRUSTACEANS_MOLLUSCS_AQUATIC_INVERTEBRATES_NE'), ('R$ 2,456,855,200.00', 'R$ 30.00'))
# (('1991', '04_DAIRY_PRODUCTS_EGGS_HONEY_EDIBLE_ANIMAL_PRODUCT_NES'), ('R$ 8,896,320,000.00', 'R$ 15.00'))
# (('1991', '05_PRODUCTS_OF_ANIMAL_ORIGIN_NES'), ('R$ 1,429,009,920.00', 'R$ 5.00'))
# (('1991', '06_LIVE_TREES_PLANTS_BULBS_ROOTS_CUT_FLOWERS_ETC'), ('R$ 6,159,489,920.00', 'R$ 15.00'))
# (('1991', '07_EDIBLE_VEGETABLES_AND_CERTAIN_ROOTS_AND_TUBERS'), ('R$ 518,759,110.00', 'R$ 25.00'))
# (('1991', '08_EDIBLE_FRUIT_NUTS_PEEL_OF_CITRUS_FRUIT_MELONS'), ('R$ 4,225,554,880.00', 'R$ 15.00'))
# (('1991', '09_COFFEE_TEA_MATE_AND_SPICES'), ('R$ 7,086,065,280.00', 'R$ 10.00'))
# (('1991', '10_CEREALS'), ('R$ 24,833,195,250.00', 'R$ 20.00'))
# (('1991', '11_MILLING_PRODUCTS_MALT_STARCHES_INULIN_WHEAT_GLUTE'), ('R$ 1,541,510,090.00', 'R$ 10.00'))
# (('1991', '12_OIL_SEED_OLEAGIC_FRUITS_GRAIN_SEED_FRUIT_ETC_NE'), ('R$ 5,732,314,350.00', 'R$ 40.00'))
# (('1991', '13_LAC_GUMS_RESINS_VEGETABLE_SAPS_AND_EXTRACTS_NES'), ('R$ 484,410,515.00', 'R$ 35.00'))
# (('1991', '14_VEGETABLE_PLAITING_MATERIALS_VEGETABLE_PRODUCTS_NES'), ('R$ 185,745,660.00', 'R$ 25.00'))
# (('1991', '15_ANIMAL_VEGETABLE_FATS_AND_OILS_CLEAVAGE_PRODUCTS_ET'), ('R$ 1,043,853,760.00', 'R$ 30.00'))
# (('1991', '16_MEAT_FISH_AND_SEAFOOD_FOOD_PREPARATIONS_NES'), ('R$ 2,947,768,715.00', 'R$ 45.00'))
# (('1991', '17_SUGARS_AND_SUGAR_CONFECTIONERY'), ('R$ 3,920,139,965.00', 'R$ 15.00'))
# (('1991', '18_COCOA_AND_COCOA_PREPARATIONS'), ('R$ 2,335,101,500.00', 'R$ 10.00'))
# (('1991', '19_CEREAL_FLOUR_STARCH_MILK_PREPARATIONS_AND_PRODUCTS'), ('R$ 2,475,750,080.00', 'R$ 30.00'))
# (('1991', '20_VEGETABLE_FRUIT_NUT_ETC_FOOD_PREPARATIONS'), ('R$ 4,500,826,880.00', 'R$ 15.00'))
# (('1991', '21_MISCELLANEOUS_EDIBLE_PREPARATIONS'), ('R$ 3,778,143,695.00', 'R$ 5.00'))
# (('1991', '22_BEVERAGES_SPIRITS_AND_VINEGAR'), ('R$ 4,344,805,120.00', 'R$ 5.00'))
# (('1991', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 6,847,164,160.00', 'R$ 10.00'))
# (('1991', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 21,219,491,880.00', 'R$ 15.00'))
# (('1991', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 2,433,021,295.00', 'R$ 15.00'))
# (('1991', '26_ORES_SLAG_AND_ASH'), ('R$ 15,692,173,050.00', 'R$ 10.00'))
# (('1991', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 148,120,696,290.00', 'R$ 10.00'))
# (('1991', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 9,476,757,760.00', 'R$ 15.00'))
# (('1991', '29_ORGANIC_CHEMICALS'), ('R$ 299,280,255.00', 'R$ 60.00'))
# (('1991', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 14,103,160,320.00', 'R$ 5.00'))
# (('1991', '31_FERTILIZERS'), ('R$ 5,266,532,850.00', 'R$ 55.00'))
# (('1991', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 6,032,195,200.00', 'R$ 50.00'))
# (('1991', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 1,826,604,960.00', 'R$ 10.00'))
# (('1991', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 2,013,864,960.00', 'R$ 10.00'))
# (('1991', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 1,512,060,320.00', 'R$ 40.00'))
# (('1991', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 386,029,550.00', 'R$ 50.00'))
# (('1991', '37_PHOTOGRAPHIC_OR_CINEMATOGRAPHIC_GOODS'), ('R$ 4,544,575,670.00', 'R$ 45.00'))
# (('1991', '38_MISCELLANEOUS_CHEMICAL_PRODUCTS'), ('R$ 863,844,580.00', 'R$ 15.00'))
# (('1991', '39_PLASTICS_AND_ARTICLES_THEREOF'), ('R$ 696,633,420.00', 'R$ 80.00'))
# (('1991', '40_RUBBER_AND_ARTICLES_THEREOF'), ('R$ 2,238,778,630.00', 'R$ 10.00'))
# (('1991', '41_RAW_HIDES_AND_SKINS_OTHER_THAN_FURSKINS_AND_LEATHER'), ('R$ 4,444,440,960.00', 'R$ 5.00'))
# (('1991', '42_ARTICLES_OF_LEATHER_ANIMAL_GUT_HARNESS_TRAVEL_GOOD'), ('R$ 4,726,620,160.00', 'R$ 40.00'))
# (('1991', '43_FURSKINS_AND_ARTIFICIAL_FUR_MANUFACTURES_THEREOF'), ('R$ 1,585,327,520.00', 'R$ 40.00'))
# (('1991', '44_WOOD_AND_ARTICLES_OF_WOOD_WOOD_CHARCOAL'), ('R$ 21,938,384,355.00', 'R$ 50.00'))
# (('1991', '45_CORK_AND_ARTICLES_OF_CORK'), ('R$ 1,519,747,360.00', 'R$ 10.00'))
# (('1991', '46_MANUFACTURES_OF_PLAITING_MATERIAL_BASKETWORK_ETC'), ('R$ 1,136,074,855.00', 'R$ 30.00'))
# (('1991', '47_PULP_OF_WOOD_FIBROUS_CELLULOSIC_MATERIAL_WASTE_ETC'), ('R$ 15,566,296,375.00', 'R$ 40.00'))
# (('1991', '48_PAPER_PAPERBOARD_ARTICLES_OF_PULP_PAPER_AND_BOARD'), ('R$ 25,587,690,755.00', 'R$ 25.00'))
# (('1991', '49_PRINTED_BOOKS_NEWSPAPERS_PICTURES_ETC'), ('R$ 3,955,289,920.00', 'R$ 25.00'))
# (('1991', '50_SILK'), ('R$ 1,610,150,560.00', 'R$ 40.00'))
# (('1991', '51_WOOL_ANIMAL_HAIR_HORSEHAIR_YARN_AND_FABRIC_THEREOF'), ('R$ 9,779,668,110.00', 'R$ 10.00'))
# (('1991', '52_COTTON'), ('R$ 3,454,324,540.00', 'R$ 5.00'))
# (('1991', '53_VEGETABLE_TEXTILE_FIBRES_NES_PAPER_YARN_WOVEN_FABRI'), ('R$ 529,293,990.00', 'R$ 5.00'))
# (('1991', '54_MANMADE_FILAMENTS'), ('R$ 372,294,760.00', 'R$ 45.00'))
# (('1991', '55_MANMADE_STAPLE_FIBRES'), ('R$ 421,220,555.00', 'R$ 130.00'))
# (('1991', '56_WADDING_FELT_NONWOVENS_YARNS_TWINE_CORDAGE_ETC'), ('R$ 3,134,194,880.00', 'R$ 10.00'))
# (('1991', '57_CARPETS_AND_OTHER_TEXTILE_FLOOR_COVERINGS'), ('R$ 3,778,780,160.00', 'R$ 40.00'))
# (('1991', '58_SPECIAL_WOVEN_OR_TUFTED_FABRIC_LACE_TAPESTRY_ETC'), ('R$ 971,138,800.00', 'R$ 30.00'))
# (('1991', '59_IMPREGNATED_COATED_OR_LAMINATED_TEXTILE_FABRIC'), ('R$ 947,395,040.00', 'R$ 20.00'))
# (('1991', '60_KNITTED_OR_CROCHETED_FABRIC'), ('R$ 1,207,070,000.00', 'R$ 40.00'))
# (('1991', '61_ARTICLES_OF_APPAREL_ACCESSORIES_KNIT_OR_CROCHET'), ('R$ 383,760,760.00', 'R$ 10.00'))
# (('1991', '62_ARTICLES_OF_APPAREL_ACCESSORIES_NOT_KNIT_OR_CROCHET'), ('R$ 825,029,810.00', 'R$ 25.00'))
# (('1991', '63_OTHER_MADE_TEXTILE_ARTICLES_SETS_WORN_CLOTHING_ETC'), ('R$ 560,342,030.00', 'R$ 25.00'))
# (('1991', '64_FOOTWEAR_GAITERS_AND_THE_LIKE_PARTS_THEREOF'), ('R$ 9,455,760,000.00', 'R$ 60.00'))
# (('1991', '65_HEADGEAR_AND_PARTS_THEREOF'), ('R$ 1,954,312,330.00', 'R$ 25.00'))
# (('1991', '66_UMBRELLAS_WALKING_STICKS_SEAT_STICKS_WHIPS_ETC'), ('R$ 785,784,970.00', 'R$ 30.00'))
# (('1991', '67_BIRD_SKIN_FEATHERS_ARTIFICIAL_FLOWERS_HUMAN_HAIR'), ('R$ 1,841,298,345.00', 'R$ 15.00'))
# (('1991', '68_STONE_PLASTER_CEMENT_ASBESTOS_MICA_ETC_ARTICLES'), ('R$ 1,099,175,040.00', 'R$ 35.00'))
# (('1991', '69_CERAMIC_PRODUCTS'), ('R$ 3,850,925,120.00', 'R$ 5.00'))
# (('1991', '70_GLASS_AND_GLASSWARE'), ('R$ 834,317,300.00', 'R$ 10.00'))
# (('1991', '71_PEARLS_PRECIOUS_STONES_METALS_COINS_ETC'), ('R$ 14,349,054,020.00', 'R$ 20.00'))
# (('1991', '72_IRON_AND_STEEL'), ('R$ 3,354,697,600.00', 'R$ 120.00'))
# (('1991', '73_ARTICLES_OF_IRON_OR_STEEL'), ('R$ 354,650,320.00', 'R$ 15.00'))
# (('1991', '74_COPPER_AND_ARTICLES_THEREOF'), ('R$ 11,424,604,160.00', 'R$ 10.00'))
# (('1991', '75_NICKEL_AND_ARTICLES_THEREOF'), ('R$ 4,251,762,965.00', 'R$ 105.00'))
# (('1991', '76_ALUMINIUM_AND_ARTICLES_THEREOF'), ('R$ 15,749,379,765.00', 'R$ 45.00'))
# (('1991', '78_LEAD_AND_ARTICLES_THEREOF'), ('R$ 613,071,120.00', 'R$ 10.00'))
# (('1991', '79_ZINC_AND_ARTICLES_THEREOF'), ('R$ 2,198,619,295.00', 'R$ 40.00'))
# (('1991', '80_TIN_AND_ARTICLES_THEREOF'), ('R$ 1,243,501,690.00', 'R$ 40.00'))
# (('1991', '81_OTHER_BASE_METALS_CERMETS_ARTICLES_THEREOF'), ('R$ 904,704,155.00', 'R$ 10.00'))
# (('1991', '82_TOOLS_IMPLEMENTS_CUTLERY_ETC_OF_BASE_METAL'), ('R$ 307,952,020.00', 'R$ 10.00'))
# (('1991', '83_MISCELLANEOUS_ARTICLES_OF_BASE_METAL'), ('R$ 1,958,215,040.00', 'R$ 10.00'))
# (('1991', '85_ELECTRICAL_ELECTRONIC_EQUIPMENT'), ('R$ 1,156,531,115.00', 'R$ 3,520.00'))
# (('1991', '86_RAILWAY_TRAMWAY_LOCOMOTIVES_ROLLING_STOCK_EQUIPMEN'), ('R$ 4,685,574,080.00', 'R$ 135.00'))
# (('1991', '87_VEHICLES_OTHER_THAN_RAILWAY_TRAMWAY'), ('R$ 44,911,566,795.00', 'R$ 165.00'))
# (('1991', '88_AIRCRAFT_SPACECRAFT_AND_PARTS_THEREOF'), ('R$ 111,153,541,120.00', 'R$ 260.00'))
# (('1991', '89_SHIPS_BOATS_AND_OTHER_FLOATING_STRUCTURES'), ('R$ 15,956,270,545.00', 'R$ 20.00'))
# (('1991', '90_OPTICAL_PHOTO_TECHNICAL_MEDICAL_ETC_APPARATUS'), ('R$ 623,207,800.00', 'R$ 95.00'))
# (('1991', '91_CLOCKS_AND_WATCHES_AND_PARTS_THEREOF'), ('R$ 2,025,420,000.00', 'R$ 75.00'))
# (('1991', '92_MUSICAL_INSTRUMENTS_PARTS_AND_ACCESSORIES'), ('R$ 3,264,205,330.00', 'R$ 45.00'))
# (('1991', '93_ARMS_AND_AMMUNITION_PARTS_AND_ACCESSORIES_THEREOF'), ('R$ 8,175,853,615.00', 'R$ 5.00'))
# (('1991', '94_FURNITURE_LIGHTING_SIGNS_PREFABRICATED_BUILDINGS'), ('R$ 7,551,630,080.00', 'R$ 10.00'))
# (('1991', '95_TOYS_GAMES_SPORTS_REQUISITES'), ('R$ 1,951,015,040.00', 'R$ 80.00'))
# (('1991', '96_MISCELLANEOUS_MANUFACTURED_ARTICLES'), ('R$ 182,699,905.00', 'R$ 40.00'))
# (('1991', '97_WORKS_OF_ART_COLLECTORS_PIECES_AND_ANTIQUES'), ('R$ 8,934,528,275.00', 'R$ 10.00'))
# (('1991', '99_COMMODITIES_NOT_SPECIFIED_ACCORDING_TO_KIND'), ('R$ 79,688,284,160.00', 'R$ 630.00'))
# (('1991', 'ALL_COMMODITIES'), ('R$ 2,544,720,169,420.00', 'R$ 52,786,310.00'))
# (('1992', '01_LIVE_ANIMALS'), ('R$ 6,275,948,645.00', 'R$ 55.00'))
# (('1992', '02_MEAT_AND_EDIBLE_MEAT_OFFAL'), ('R$ 8,979,748,055.00', 'R$ 25.00'))
# (('1992', '03_FISH_CRUSTACEANS_MOLLUSCS_AQUATIC_INVERTEBRATES_NE'), ('R$ 2,750,409,960.00', 'R$ 25.00'))
# (('1992', '04_DAIRY_PRODUCTS_EGGS_HONEY_EDIBLE_ANIMAL_PRODUCT_NES'), ('R$ 10,077,680,640.00', 'R$ 5.00'))
# (('1992', '05_PRODUCTS_OF_ANIMAL_ORIGIN_NES'), ('R$ 1,715,880,000.00', 'R$ 10.00'))
# (('1992', '06_LIVE_TREES_PLANTS_BULBS_ROOTS_CUT_FLOWERS_ETC'), ('R$ 10,999,205,120.00', 'R$ 15.00'))
# (('1992', '07_EDIBLE_VEGETABLES_AND_CERTAIN_ROOTS_AND_TUBERS'), ('R$ 716,310,055.00', 'R$ 5.00'))
# (('1992', '08_EDIBLE_FRUIT_NUTS_PEEL_OF_CITRUS_FRUIT_MELONS'), ('R$ 3,915,085,120.00', 'R$ 5.00'))
# (('1992', '09_COFFEE_TEA_MATE_AND_SPICES'), ('R$ 6,341,059,840.00', 'R$ 5.00'))
# (('1992', '10_CEREALS'), ('R$ 23,849,415,445.00', 'R$ 10.00'))
# (('1992', '11_MILLING_PRODUCTS_MALT_STARCHES_INULIN_WHEAT_GLUTE'), ('R$ 1,671,321,510.00', 'R$ 5.00'))
# (('1992', '12_OIL_SEED_OLEAGIC_FRUITS_GRAIN_SEED_FRUIT_ETC_NE'), ('R$ 6,179,359,250.00', 'R$ 20.00'))
# (('1992', '13_LAC_GUMS_RESINS_VEGETABLE_SAPS_AND_EXTRACTS_NES'), ('R$ 622,726,745.00', 'R$ 5.00'))
# (('1992', '14_VEGETABLE_PLAITING_MATERIALS_VEGETABLE_PRODUCTS_NES'), ('R$ 172,146,080.00', 'R$ 10.00'))
# (('1992', '15_ANIMAL_VEGETABLE_FATS_AND_OILS_CLEAVAGE_PRODUCTS_ET'), ('R$ 2,287,598,560.00', 'R$ 5.00'))
# (('1992', '16_MEAT_FISH_AND_SEAFOOD_FOOD_PREPARATIONS_NES'), ('R$ 3,402,426,905.00', 'R$ 50.00'))
# (('1992', '17_SUGARS_AND_SUGAR_CONFECTIONERY'), ('R$ 3,684,077,430.00', 'R$ 20.00'))
# (('1992', '18_COCOA_AND_COCOA_PREPARATIONS'), ('R$ 2,162,765,835.00', 'R$ 10.00'))
# (('1992', '19_CEREAL_FLOUR_STARCH_MILK_PREPARATIONS_AND_PRODUCTS'), ('R$ 2,599,644,960.00', 'R$ 45.00'))
# (('1992', '20_VEGETABLE_FRUIT_NUT_ETC_FOOD_PREPARATIONS'), ('R$ 5,265,508,160.00', 'R$ 15.00'))
# (('1992', '21_MISCELLANEOUS_EDIBLE_PREPARATIONS'), ('R$ 5,978,149,760.00', 'R$ 5.00'))
# (('1992', '22_BEVERAGES_SPIRITS_AND_VINEGAR'), ('R$ 4,846,384,960.00', 'R$ 25.00'))
# (('1992', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 7,983,324,160.00', 'R$ 10.00'))
# (('1992', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 20,995,395,380.00', 'R$ 25.00'))
# (('1992', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 1,494,181,600.00', 'R$ 5.00'))
# (('1992', '26_ORES_SLAG_AND_ASH'), ('R$ 13,886,531,415.00', 'R$ 5.00'))
# (('1992', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 148,105,347,450.00', 'R$ 10.00'))
# (('1992', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 8,124,620,125.00', 'R$ 20.00'))
# (('1992', '29_ORGANIC_CHEMICALS'), ('R$ 547,736,950.00', 'R$ 35.00'))
# (('1992', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 15,882,179,840.00', 'R$ 25.00'))
# (('1992', '31_FERTILIZERS'), ('R$ 5,741,599,095.00', 'R$ 15.00'))
# (('1992', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 6,297,994,880.00', 'R$ 30.00'))
# (('1992', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 1,988,644,960.00', 'R$ 130.00'))
# (('1992', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 2,304,049,920.00', 'R$ 95.00'))
# (('1992', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 1,963,723,520.00', 'R$ 10.00'))
# (('1992', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 699,369,885.00', 'R$ 15.00'))
# (('1992', '37_PHOTOGRAPHIC_OR_CINEMATOGRAPHIC_GOODS'), ('R$ 5,136,940,215.00', 'R$ 10.00'))
# (('1992', '38_MISCELLANEOUS_CHEMICAL_PRODUCTS'), ('R$ 918,563,840.00', 'R$ 10.00'))
# (('1992', '39_PLASTICS_AND_ARTICLES_THEREOF'), ('R$ 708,819,620.00', 'R$ 5.00'))
# (('1992', '40_RUBBER_AND_ARTICLES_THEREOF'), ('R$ 2,475,774,240.00', 'R$ 35.00'))
# (('1992', '41_RAW_HIDES_AND_SKINS_OTHER_THAN_FURSKINS_AND_LEATHER'), ('R$ 3,981,400,960.00', 'R$ 25.00'))
# (('1992', '42_ARTICLES_OF_LEATHER_ANIMAL_GUT_HARNESS_TRAVEL_GOOD'), ('R$ 4,052,344,960.00', 'R$ 40.00'))
# (('1992', '43_FURSKINS_AND_ARTIFICIAL_FUR_MANUFACTURES_THEREOF'), ('R$ 1,635,913,760.00', 'R$ 10.00'))
# (('1992', '44_WOOD_AND_ARTICLES_OF_WOOD_WOOD_CHARCOAL'), ('R$ 26,454,912,000.00', 'R$ 20.00'))
# (('1992', '45_CORK_AND_ARTICLES_OF_CORK'), ('R$ 1,687,316,320.00', 'R$ 40.00'))
# (('1992', '46_MANUFACTURES_OF_PLAITING_MATERIAL_BASKETWORK_ETC'), ('R$ 1,764,226,215.00', 'R$ 5.00'))
# (('1992', '47_PULP_OF_WOOD_FIBROUS_CELLULOSIC_MATERIAL_WASTE_ETC'), ('R$ 14,884,005,120.00', 'R$ 15.00'))
# (('1992', '48_PAPER_PAPERBOARD_ARTICLES_OF_PULP_PAPER_AND_BOARD'), ('R$ 23,829,191,680.00', 'R$ 30.00'))
# (('1992', '49_PRINTED_BOOKS_NEWSPAPERS_PICTURES_ETC'), ('R$ 4,342,550,080.00', 'R$ 10.00'))
# (('1992', '50_SILK'), ('R$ 2,504,798,295.00', 'R$ 20.00'))
# (('1992', '51_WOOL_ANIMAL_HAIR_HORSEHAIR_YARN_AND_FABRIC_THEREOF'), ('R$ 9,016,138,610.00', 'R$ 20.00'))
# (('1992', '52_COTTON'), ('R$ 3,274,855,055.00', 'R$ 75.00'))
# (('1992', '53_VEGETABLE_TEXTILE_FIBRES_NES_PAPER_YARN_WOVEN_FABRI'), ('R$ 557,763,630.00', 'R$ 5.00'))
# (('1992', '54_MANMADE_FILAMENTS'), ('R$ 2,986,449,930.00', 'R$ 95.00'))
# (('1992', '55_MANMADE_STAPLE_FIBRES'), ('R$ 1,594,659,130.00', 'R$ 5.00'))
# (('1992', '56_WADDING_FELT_NONWOVENS_YARNS_TWINE_CORDAGE_ETC'), ('R$ 3,563,619,840.00', 'R$ 5.00'))
# (('1992', '57_CARPETS_AND_OTHER_TEXTILE_FLOOR_COVERINGS'), ('R$ 3,975,605,120.00', 'R$ 10.00'))
# (('1992', '58_SPECIAL_WOVEN_OR_TUFTED_FABRIC_LACE_TAPESTRY_ETC'), ('R$ 1,206,961,760.00', 'R$ 65.00'))
# (('1992', '59_IMPREGNATED_COATED_OR_LAMINATED_TEXTILE_FABRIC'), ('R$ 1,481,936,285.00', 'R$ 15.00'))
# (('1992', '60_KNITTED_OR_CROCHETED_FABRIC'), ('R$ 1,903,703,790.00', 'R$ 5.00'))
# (('1992', '61_ARTICLES_OF_APPAREL_ACCESSORIES_KNIT_OR_CROCHET'), ('R$ 422,052,880.00', 'R$ 10.00'))
# (('1992', '62_ARTICLES_OF_APPAREL_ACCESSORIES_NOT_KNIT_OR_CROCHET'), ('R$ 917,175,360.00', 'R$ 10.00'))
# (('1992', '63_OTHER_MADE_TEXTILE_ARTICLES_SETS_WORN_CLOTHING_ETC'), ('R$ 1,719,904,165.00', 'R$ 5.00'))
# (('1992', '64_FOOTWEAR_GAITERS_AND_THE_LIKE_PARTS_THEREOF'), ('R$ 9,719,534,720.00', 'R$ 15.00'))
# (('1992', '65_HEADGEAR_AND_PARTS_THEREOF'), ('R$ 2,744,781,455.00', 'R$ 10.00'))
# (('1992', '66_UMBRELLAS_WALKING_STICKS_SEAT_STICKS_WHIPS_ETC'), ('R$ 1,107,080,575.00', 'R$ 20.00'))
# (('1992', '67_BIRD_SKIN_FEATHERS_ARTIFICIAL_FLOWERS_HUMAN_HAIR'), ('R$ 2,350,746,395.00', 'R$ 15.00'))
# (('1992', '68_STONE_PLASTER_CEMENT_ASBESTOS_MICA_ETC_ARTICLES'), ('R$ 1,409,600,000.00', 'R$ 60.00'))
# (('1992', '69_CERAMIC_PRODUCTS'), ('R$ 4,835,704,960.00', 'R$ 10.00'))
# (('1992', '70_GLASS_AND_GLASSWARE'), ('R$ 896,157,680.00', 'R$ 25.00'))
# (('1992', '71_PEARLS_PRECIOUS_STONES_METALS_COINS_ETC'), ('R$ 16,411,786,220.00', 'R$ 60.00'))
# (('1992', '72_IRON_AND_STEEL'), ('R$ 3,477,950,080.00', 'R$ 5.00'))
# (('1992', '73_ARTICLES_OF_IRON_OR_STEEL'), ('R$ 878,846,400.00', 'R$ 5.00'))
# (('1992', '74_COPPER_AND_ARTICLES_THEREOF'), ('R$ 11,817,733,120.00', 'R$ 50.00'))
# (('1992', '75_NICKEL_AND_ARTICLES_THEREOF'), ('R$ 3,701,910,080.00', 'R$ 45.00'))
# (('1992', '76_ALUMINIUM_AND_ARTICLES_THEREOF'), ('R$ 12,591,524,715.00', 'R$ 10.00'))
# (('1992', '78_LEAD_AND_ARTICLES_THEREOF'), ('R$ 649,908,720.00', 'R$ 30.00'))
# (('1992', '79_ZINC_AND_ARTICLES_THEREOF'), ('R$ 3,042,614,210.00', 'R$ 5.00'))
# (('1992', '80_TIN_AND_ARTICLES_THEREOF'), ('R$ 1,417,883,645.00', 'R$ 45.00'))
# (('1992', '81_OTHER_BASE_METALS_CERMETS_ARTICLES_THEREOF'), ('R$ 1,132,689,425.00', 'R$ 5.00'))
# (('1992', '82_TOOLS_IMPLEMENTS_CUTLERY_ETC_OF_BASE_METAL'), ('R$ 407,982,800.00', 'R$ 30.00'))
# (('1992', '83_MISCELLANEOUS_ARTICLES_OF_BASE_METAL'), ('R$ 2,217,635,040.00', 'R$ 60.00'))
# (('1992', '84_NUCLEAR_REACTORS_BOILERS_MACHINERY_ETC'), ('R$ 280,739,340.00', 'R$ 160.00'))
# (('1992', '85_ELECTRICAL_ELECTRONIC_EQUIPMENT'), ('R$ 1,396,404,980.00', 'R$ 60.00'))
# (('1992', '86_RAILWAY_TRAMWAY_LOCOMOTIVES_ROLLING_STOCK_EQUIPMEN'), ('R$ 5,587,094,400.00', 'R$ 25.00'))
# (('1992', '87_VEHICLES_OTHER_THAN_RAILWAY_TRAMWAY'), ('R$ 45,083,269,120.00', 'R$ 50.00'))
# (('1992', '88_AIRCRAFT_SPACECRAFT_AND_PARTS_THEREOF'), ('R$ 117,781,381,120.00', 'R$ 130.00'))
# (('1992', '89_SHIPS_BOATS_AND_OTHER_FLOATING_STRUCTURES'), ('R$ 21,017,389,710.00', 'R$ 75.00'))
# (('1992', '90_OPTICAL_PHOTO_TECHNICAL_MEDICAL_ETC_APPARATUS'), ('R$ 684,779,535.00', 'R$ 5.00'))
# (('1992', '91_CLOCKS_AND_WATCHES_AND_PARTS_THEREOF'), ('R$ 2,170,435,040.00', 'R$ 25.00'))
# (('1992', '92_MUSICAL_INSTRUMENTS_PARTS_AND_ACCESSORIES'), ('R$ 3,098,571,155.00', 'R$ 10.00'))
# (('1992', '93_ARMS_AND_AMMUNITION_PARTS_AND_ACCESSORIES_THEREOF'), ('R$ 8,992,142,575.00', 'R$ 20.00'))
# (('1992', '94_FURNITURE_LIGHTING_SIGNS_PREFABRICATED_BUILDINGS'), ('R$ 8,844,800,000.00', 'R$ 25.00'))
# (('1992', '95_TOYS_GAMES_SPORTS_REQUISITES'), ('R$ 5,109,423,465.00', 'R$ 10.00'))
# (('1992', '96_MISCELLANEOUS_MANUFACTURED_ARTICLES'), ('R$ 565,896,700.00', 'R$ 5.00'))
# (('1992', '97_WORKS_OF_ART_COLLECTORS_PIECES_AND_ANTIQUES'), ('R$ 6,306,546,925.00', 'R$ 10.00'))
# (('1992', '99_COMMODITIES_NOT_SPECIFIED_ACCORDING_TO_KIND'), ('R$ 86,411,247,800.00', 'R$ 480.00'))
# (('1992', 'ALL_COMMODITIES'), ('R$ 2,767,482,367,855.00', 'R$ 15,376,050.00'))
# (('1993', '01_LIVE_ANIMALS'), ('R$ 6,782,629,470.00', 'R$ 5.00'))
# (('1993', '02_MEAT_AND_EDIBLE_MEAT_OFFAL'), ('R$ 9,257,333,465.00', 'R$ 65.00'))
# (('1993', '03_FISH_CRUSTACEANS_MOLLUSCS_AQUATIC_INVERTEBRATES_NE'), ('R$ 2,333,208,160.00', 'R$ 15.00'))
# (('1993', '04_DAIRY_PRODUCTS_EGGS_HONEY_EDIBLE_ANIMAL_PRODUCT_NES'), ('R$ 9,013,084,160.00', 'R$ 10.00'))
# (('1993', '05_PRODUCTS_OF_ANIMAL_ORIGIN_NES'), ('R$ 1,483,084,960.00', 'R$ 5.00'))
# (('1993', '06_LIVE_TREES_PLANTS_BULBS_ROOTS_CUT_FLOWERS_ETC'), ('R$ 9,040,807,040.00', 'R$ 5.00'))
# (('1993', '07_EDIBLE_VEGETABLES_AND_CERTAIN_ROOTS_AND_TUBERS'), ('R$ 650,947,020.00', 'R$ 5.00'))
# (('1993', '08_EDIBLE_FRUIT_NUTS_PEEL_OF_CITRUS_FRUIT_MELONS'), ('R$ 3,076,784,960.00', 'R$ 5.00'))
# (('1993', '09_COFFEE_TEA_MATE_AND_SPICES'), ('R$ 6,177,495,040.00', 'R$ 5.00'))
# (('1993', '10_CEREALS'), ('R$ 22,394,180,050.00', 'R$ 15.00'))
# (('1993', '11_MILLING_PRODUCTS_MALT_STARCHES_INULIN_WHEAT_GLUTE'), ('R$ 4,161,681,600.00', 'R$ 10.00'))
# (('1993', '12_OIL_SEED_OLEAGIC_FRUITS_GRAIN_SEED_FRUIT_ETC_NE'), ('R$ 6,877,012,720.00', 'R$ 5.00'))
# (('1993', '13_LAC_GUMS_RESINS_VEGETABLE_SAPS_AND_EXTRACTS_NES'), ('R$ 495,220,745.00', 'R$ 25.00'))
# (('1993', '14_VEGETABLE_PLAITING_MATERIALS_VEGETABLE_PRODUCTS_NES'), ('R$ 164,644,760.00', 'R$ 20.00'))
# (('1993', '15_ANIMAL_VEGETABLE_FATS_AND_OILS_CLEAVAGE_PRODUCTS_ET'), ('R$ 2,968,035,840.00', 'R$ 10.00'))
# (('1993', '16_MEAT_FISH_AND_SEAFOOD_FOOD_PREPARATIONS_NES'), ('R$ 4,310,606,845.00', 'R$ 5.00'))
# (('1993', '17_SUGARS_AND_SUGAR_CONFECTIONERY'), ('R$ 3,806,869,435.00', 'R$ 5.00'))
# (('1993', '18_COCOA_AND_COCOA_PREPARATIONS'), ('R$ 2,168,626,960.00', 'R$ 30.00'))
# (('1993', '19_CEREAL_FLOUR_STARCH_MILK_PREPARATIONS_AND_PRODUCTS'), ('R$ 2,374,550,080.00', 'R$ 10.00'))
# (('1993', '20_VEGETABLE_FRUIT_NUT_ETC_FOOD_PREPARATIONS'), ('R$ 4,133,624,960.00', 'R$ 10.00'))
# (('1993', '21_MISCELLANEOUS_EDIBLE_PREPARATIONS'), ('R$ 7,341,624,320.00', 'R$ 10.00'))
# (('1993', '22_BEVERAGES_SPIRITS_AND_VINEGAR'), ('R$ 3,751,050,560.00', 'R$ 15.00'))
# (('1993', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 9,083,028,480.00', 'R$ 25.00'))
# (('1993', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 19,666,340,740.00', 'R$ 15.00'))
# (('1993', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 1,170,036,900.00', 'R$ 5.00'))
# (('1993', '26_ORES_SLAG_AND_ASH'), ('R$ 13,274,562,075.00', 'R$ 10.00'))
# (('1993', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 138,857,193,385.00', 'R$ 5.00'))
# (('1993', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 7,941,064,420.00', 'R$ 50.00'))
# (('1993', '29_ORGANIC_CHEMICALS'), ('R$ 510,279,325.00', 'R$ 40.00'))
# (('1993', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 16,339,910,400.00', 'R$ 25.00'))
# (('1993', '31_FERTILIZERS'), ('R$ 4,632,891,000.00', 'R$ 5.00'))
# (('1993', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 5,657,349,760.00', 'R$ 5.00'))
# (('1993', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 1,642,740,000.00', 'R$ 5.00'))
# (('1993', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 2,185,164,960.00', 'R$ 45.00'))
# (('1993', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 1,964,127,680.00', 'R$ 10.00'))
# (('1993', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 662,822,680.00', 'R$ 10.00'))
# ...
# (('2015', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 48,366,246,460.00', 'R$ 5.00'))
# (('2015', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 16,934,054,425.00', 'R$ 5.00'))
# (('2015', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 8,890,289,290.00', 'R$ 5.00'))
# (('2015', '26_ORES_SLAG_AND_ASH'), ('R$ 276,097,507,280.00', 'R$ 5.00'))
# (('2015', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 1,018,104,770,695.00', 'R$ 5.00'))
# (('2015', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 24,270,327,300.00', 'R$ 5.00'))
# (('2015', '29_ORGANIC_CHEMICALS'), ('R$ 17,392,746,380.00', 'R$ 5.00'))
# (('2015', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 374,024,780,810.00', 'R$ 5.00'))
# (('2015', '31_FERTILIZERS'), ('R$ 26,722,516,240.00', 'R$ 5.00'))
# (('2015', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 8,864,825,650.00', 'R$ 5.00'))
# (('2015', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 40,747,556,090.00', 'R$ 5.00'))
# (('2015', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 8,802,463,645.00', 'R$ 5.00'))
# (('2015', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 7,915,723,795.00', 'R$ 5.00'))
# (('2015', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 4,233,816,295.00', 'R$ 5.00'))
# (('2015', '37_PHOTOGRAPHIC_OR_CINEMATOGRAPHIC_GOODS'), ('R$ 11,783,946,755.00', 'R$ 10.00'))
# (('2015', '38_MISCELLANEOUS_CHEMICAL_PRODUCTS'), ('R$ 30,396,538,895.00', 'R$ 5.00'))
# (('2015', '39_PLASTICS_AND_ARTICLES_THEREOF'), ('R$ 10,980,378,265.00', 'R$ 5.00'))
# (('2015', '40_RUBBER_AND_ARTICLES_THEREOF'), ('R$ 36,221,685,345.00', 'R$ 5.00'))
# (('2015', '41_RAW_HIDES_AND_SKINS_OTHER_THAN_FURSKINS_AND_LEATHER'), ('R$ 12,431,618,980.00', 'R$ 5.00'))
# (('2015', '42_ARTICLES_OF_LEATHER_ANIMAL_GUT_HARNESS_TRAVEL_GOOD'), ('R$ 50,109,283,475.00', 'R$ 5.00'))
# (('2015', '43_FURSKINS_AND_ARTIFICIAL_FUR_MANUFACTURES_THEREOF'), ('R$ 12,230,103,160.00', 'R$ 5.00'))
# (('2015', '44_WOOD_AND_ARTICLES_OF_WOOD_WOOD_CHARCOAL'), ('R$ 33,241,384,575.00', 'R$ 5.00'))
# (('2015', '45_CORK_AND_ARTICLES_OF_CORK'), ('R$ 2,293,166,225.00', 'R$ 10.00'))
# (('2015', '46_MANUFACTURES_OF_PLAITING_MATERIAL_BASKETWORK_ETC'), ('R$ 4,746,604,575.00', 'R$ 5.00'))
# (('2015', '47_PULP_OF_WOOD_FIBROUS_CELLULOSIC_MATERIAL_WASTE_ETC'), ('R$ 26,714,374,285.00', 'R$ 5.00'))
# (('2015', '48_PAPER_PAPERBOARD_ARTICLES_OF_PULP_PAPER_AND_BOARD'), ('R$ 9,134,196,460.00', 'R$ 5.00'))
# (('2015', '49_PRINTED_BOOKS_NEWSPAPERS_PICTURES_ETC'), ('R$ 12,365,277,260.00', 'R$ 5.00'))
# (('2015', '50_SILK'), ('R$ 3,431,454,495.00', 'R$ 5.00'))
# (('2015', '51_WOOL_ANIMAL_HAIR_HORSEHAIR_YARN_AND_FABRIC_THEREOF'), ('R$ 10,649,813,920.00', 'R$ 5.00'))
# (('2015', '52_COTTON'), ('R$ 12,815,876,595.00', 'R$ 5.00'))
# (('2015', '53_VEGETABLE_TEXTILE_FIBRES_NES_PAPER_YARN_WOVEN_FABRI'), ('R$ 3,442,925,320.00', 'R$ 5.00'))
# (('2015', '54_MANMADE_FILAMENTS'), ('R$ 25,098,436,650.00', 'R$ 5.00'))
# (('2015', '55_MANMADE_STAPLE_FIBRES'), ('R$ 5,491,749,455.00', 'R$ 5.00'))
# (('2015', '56_WADDING_FELT_NONWOVENS_YARNS_TWINE_CORDAGE_ETC'), ('R$ 12,430,447,630.00', 'R$ 5.00'))
# (('2015', '57_CARPETS_AND_OTHER_TEXTILE_FLOOR_COVERINGS'), ('R$ 4,806,000,275.00', 'R$ 5.00'))
# (('2015', '58_SPECIAL_WOVEN_OR_TUFTED_FABRIC_LACE_TAPESTRY_ETC'), ('R$ 3,825,690,405.00', 'R$ 5.00'))
# (('2015', '59_IMPREGNATED_COATED_OR_LAMINATED_TEXTILE_FABRIC'), ('R$ 10,734,534,150.00', 'R$ 5.00'))
# (('2015', '60_KNITTED_OR_CROCHETED_FABRIC'), ('R$ 26,505,233,405.00', 'R$ 5.00'))
# (('2015', '61_ARTICLES_OF_APPAREL_ACCESSORIES_KNIT_OR_CROCHET'), ('R$ 28,944,510,270.00', 'R$ 5.00'))
# (('2015', '62_ARTICLES_OF_APPAREL_ACCESSORIES_NOT_KNIT_OR_CROCHET'), ('R$ 25,151,088,235.00', 'R$ 20.00'))
# (('2015', '63_OTHER_MADE_TEXTILE_ARTICLES_SETS_WORN_CLOTHING_ETC'), ('R$ 23,237,254,730.00', 'R$ 5.00'))
# (('2015', '64_FOOTWEAR_GAITERS_AND_THE_LIKE_PARTS_THEREOF'), ('R$ 98,002,310,400.00', 'R$ 5.00'))
# (('2015', '65_HEADGEAR_AND_PARTS_THEREOF'), ('R$ 14,634,230,665.00', 'R$ 5.00'))
# (('2015', '66_UMBRELLAS_WALKING_STICKS_SEAT_STICKS_WHIPS_ETC'), ('R$ 5,858,791,350.00', 'R$ 15.00'))
# (('2015', '67_BIRD_SKIN_FEATHERS_ARTIFICIAL_FLOWERS_HUMAN_HAIR'), ('R$ 11,010,079,715.00', 'R$ 5.00'))
# (('2015', '68_STONE_PLASTER_CEMENT_ASBESTOS_MICA_ETC_ARTICLES'), ('R$ 17,615,240,115.00', 'R$ 5.00'))
# (('2015', '69_CERAMIC_PRODUCTS'), ('R$ 31,814,368,010.00', 'R$ 5.00'))
# (('2015', '70_GLASS_AND_GLASSWARE'), ('R$ 7,578,701,475.00', 'R$ 5.00'))
# (('2015', '71_PEARLS_PRECIOUS_STONES_METALS_COINS_ETC'), ('R$ 371,379,659,180.00', 'R$ 5.00'))
# (('2015', '72_IRON_AND_STEEL'), ('R$ 9,979,778,385.00', 'R$ 5.00'))
# (('2015', '73_ARTICLES_OF_IRON_OR_STEEL'), ('R$ 9,452,800,090.00', 'R$ 5.00'))
# (('2015', '74_COPPER_AND_ARTICLES_THEREOF'), ('R$ 103,101,617,720.00', 'R$ 5.00'))
# (('2015', '75_NICKEL_AND_ARTICLES_THEREOF'), ('R$ 17,392,308,545.00', 'R$ 5.00'))
# (('2015', '76_ALUMINIUM_AND_ARTICLES_THEREOF'), ('R$ 27,611,564,860.00', 'R$ 5.00'))
# (('2015', '78_LEAD_AND_ARTICLES_THEREOF'), ('R$ 3,943,938,100.00', 'R$ 5.00'))
# (('2015', '79_ZINC_AND_ARTICLES_THEREOF'), ('R$ 5,253,411,390.00', 'R$ 5.00'))
# (('2015', '80_TIN_AND_ARTICLES_THEREOF'), ('R$ 5,768,113,515.00', 'R$ 5.00'))
# (('2015', '81_OTHER_BASE_METALS_CERMETS_ARTICLES_THEREOF'), ('R$ 6,857,991,030.00', 'R$ 5.00'))
# (('2015', '82_TOOLS_IMPLEMENTS_CUTLERY_ETC_OF_BASE_METAL'), ('R$ 5,395,840,410.00', 'R$ 5.00'))
# (('2015', '83_MISCELLANEOUS_ARTICLES_OF_BASE_METAL'), ('R$ 14,902,209,390.00', 'R$ 5.00'))
# (('2015', '84_NUCLEAR_REACTORS_BOILERS_MACHINERY_ETC'), ('R$ 18,155,793,340.00', 'R$ 5.00'))
# (('2015', '85_ELECTRICAL_ELECTRONIC_EQUIPMENT'), ('R$ 19,760,652,150.00', 'R$ 5.00'))
# (('2015', '86_RAILWAY_TRAMWAY_LOCOMOTIVES_ROLLING_STOCK_EQUIPMEN'), ('R$ 38,374,514,430.00', 'R$ 5.00'))
# (('2015', '87_VEHICLES_OTHER_THAN_RAILWAY_TRAMWAY'), ('R$ 180,569,490,540.00', 'R$ 15.00'))
# (('2015', '88_AIRCRAFT_SPACECRAFT_AND_PARTS_THEREOF'), ('R$ 255,967,385,855.00', 'R$ 5.00'))
# (('2015', '89_SHIPS_BOATS_AND_OTHER_FLOATING_STRUCTURES'), ('R$ 81,406,941,410.00', 'R$ 10.00'))
# (('2015', '90_OPTICAL_PHOTO_TECHNICAL_MEDICAL_ETC_APPARATUS'), ('R$ 16,249,053,835.00', 'R$ 5.00'))
# (('2015', '91_CLOCKS_AND_WATCHES_AND_PARTS_THEREOF'), ('R$ 20,535,737,720.00', 'R$ 5.00'))
# (('2015', '92_MUSICAL_INSTRUMENTS_PARTS_AND_ACCESSORIES'), ('R$ 1,771,451,680.00', 'R$ 5.00'))
# (('2015', '93_ARMS_AND_AMMUNITION_PARTS_AND_ACCESSORIES_THEREOF'), ('R$ 17,087,666,655.00', 'R$ 10.00'))
# (('2015', '94_FURNITURE_LIGHTING_SIGNS_PREFABRICATED_BUILDINGS'), ('R$ 84,711,619,585.00', 'R$ 15.00'))
# (('2015', '95_TOYS_GAMES_SPORTS_REQUISITES'), ('R$ 78,318,576,760.00', 'R$ 10.00'))
# (('2015', '96_MISCELLANEOUS_MANUFACTURED_ARTICLES'), ('R$ 8,685,283,130.00', 'R$ 5.00'))
# (('2015', '97_WORKS_OF_ART_COLLECTORS_PIECES_AND_ANTIQUES'), ('R$ 41,882,480,925.00', 'R$ 5.00'))
# (('2015', '99_COMMODITIES_NOT_SPECIFIED_ACCORDING_TO_KIND'), ('R$ 889,600,243,430.00', 'R$ 40.00'))
# (('2015', 'ALL_COMMODITIES'), ('R$ 11,567,122,846,635.00', 'R$ 610.00'))
# (('2016', '01_LIVE_ANIMALS'), ('R$ 8,362,467,815.00', 'R$ 10.00'))
# (('2016', '02_MEAT_AND_EDIBLE_MEAT_OFFAL'), ('R$ 19,762,436,890.00', 'R$ 5.00'))
# (('2016', '03_FISH_CRUSTACEANS_MOLLUSCS_AQUATIC_INVERTEBRATES_NE'), ('R$ 19,178,237,195.00', 'R$ 5.00'))
# (('2016', '04_DAIRY_PRODUCTS_EGGS_HONEY_EDIBLE_ANIMAL_PRODUCT_NES'), ('R$ 15,856,250,235.00', 'R$ 5.00'))
# (('2016', '05_PRODUCTS_OF_ANIMAL_ORIGIN_NES'), ('R$ 5,369,423,955.00', 'R$ 5.00'))
# (('2016', '06_LIVE_TREES_PLANTS_BULBS_ROOTS_CUT_FLOWERS_ETC'), ('R$ 19,254,197,920.00', 'R$ 5.00'))
# (('2016', '07_EDIBLE_VEGETABLES_AND_CERTAIN_ROOTS_AND_TUBERS'), ('R$ 13,223,569,010.00', 'R$ 5.00'))
# (('2016', '08_EDIBLE_FRUIT_NUTS_PEEL_OF_CITRUS_FRUIT_MELONS'), ('R$ 13,710,026,020.00', 'R$ 5.00'))
# (('2016', '09_COFFEE_TEA_MATE_AND_SPICES'), ('R$ 24,214,883,880.00', 'R$ 5.00'))
# (('2016', '10_CEREALS'), ('R$ 50,246,976,365.00', 'R$ 5.00'))
# (('2016', '11_MILLING_PRODUCTS_MALT_STARCHES_INULIN_WHEAT_GLUTE'), ('R$ 3,645,377,470.00', 'R$ 5.00'))
# (('2016', '12_OIL_SEED_OLEAGIC_FRUITS_GRAIN_SEED_FRUIT_ETC_NE'), ('R$ 169,905,747,395.00', 'R$ 5.00'))
# (('2016', '13_LAC_GUMS_RESINS_VEGETABLE_SAPS_AND_EXTRACTS_NES'), ('R$ 3,647,468,515.00', 'R$ 15.00'))
# (('2016', '14_VEGETABLE_PLAITING_MATERIALS_VEGETABLE_PRODUCTS_NES'), ('R$ 537,317,895.00', 'R$ 10.00'))
# (('2016', '15_ANIMAL_VEGETABLE_FATS_AND_OILS_CLEAVAGE_PRODUCTS_ET'), ('R$ 55,299,235,360.00', 'R$ 5.00'))
# (('2016', '16_MEAT_FISH_AND_SEAFOOD_FOOD_PREPARATIONS_NES'), ('R$ 9,793,802,970.00', 'R$ 5.00'))
# (('2016', '17_SUGARS_AND_SUGAR_CONFECTIONERY'), ('R$ 41,410,804,930.00', 'R$ 5.00'))
# (('2016', '18_COCOA_AND_COCOA_PREPARATIONS'), ('R$ 12,771,770,270.00', 'R$ 5.00'))
# (('2016', '19_CEREAL_FLOUR_STARCH_MILK_PREPARATIONS_AND_PRODUCTS'), ('R$ 15,352,396,180.00', 'R$ 5.00'))
# (('2016', '20_VEGETABLE_FRUIT_NUT_ETC_FOOD_PREPARATIONS'), ('R$ 8,266,582,855.00', 'R$ 5.00'))
# (('2016', '21_MISCELLANEOUS_EDIBLE_PREPARATIONS'), ('R$ 25,435,336,870.00', 'R$ 10.00'))
# (('2016', '22_BEVERAGES_SPIRITS_AND_VINEGAR'), ('R$ 28,057,893,515.00', 'R$ 10.00'))
# (('2016', '23_RESIDUES_WASTES_OF_FOOD_INDUSTRY_ANIMAL_FODDER'), ('R$ 49,852,943,450.00', 'R$ 5.00'))
# (('2016', '24_TOBACCO_AND_MANUFACTURED_TOBACCO_SUBSTITUTES'), ('R$ 17,821,695,850.00', 'R$ 15.00'))
# (('2016', '25_SALT_SULPHUR_EARTH_STONE_PLASTER_LIME_AND_CEMENT'), ('R$ 5,790,706,670.00', 'R$ 5.00'))
# (('2016', '26_ORES_SLAG_AND_ASH'), ('R$ 284,328,057,735.00', 'R$ 5.00'))
# (('2016', '27_MINERAL_FUELS_OILS_DISTILLATION_PRODUCTS_ETC'), ('R$ 583,303,742,205.00', 'R$ 5.00'))
# (('2016', '28_INORGANIC_CHEMICALS_PRECIOUS_METAL_COMPOUND_ISOTOPE'), ('R$ 20,515,515,100.00', 'R$ 5.00'))
# (('2016', '29_ORGANIC_CHEMICALS'), ('R$ 14,463,708,120.00', 'R$ 5.00'))
# (('2016', '30_PHARMACEUTICAL_PRODUCTS'), ('R$ 187,335,962,915.00', 'R$ 5.00'))
# (('2016', '31_FERTILIZERS'), ('R$ 17,652,257,545.00', 'R$ 5.00'))
# (('2016', '32_TANNING_DYEING_EXTRACTS_TANNINS_DERIVS_PIGMENTS_ET'), ('R$ 6,990,898,105.00', 'R$ 5.00'))
# (('2016', '33_ESSENTIAL_OILS_PERFUMES_COSMETICS_TOILETERIES'), ('R$ 40,178,955,710.00', 'R$ 5.00'))
# (('2016', '34_SOAPS_LUBRICANTS_WAXES_CANDLES_MODELLING_PASTES'), ('R$ 8,564,761,890.00', 'R$ 5.00'))
# (('2016', '35_ALBUMINOIDS_MODIFIED_STARCHES_GLUES_ENZYMES'), ('R$ 7,684,299,315.00', 'R$ 5.00'))
# (('2016', '36_EXPLOSIVES_PYROTECHNICS_MATCHES_PYROPHORICS_ETC'), ('R$ 3,660,886,000.00', 'R$ 15.00'))
# (('2016', '37_PHOTOGRAPHIC_OR_CINEMATOGRAPHIC_GOODS'), ('R$ 12,896,594,575.00', 'R$ 5.00'))
# (('2016', '38_MISCELLANEOUS_CHEMICAL_PRODUCTS'), ('R$ 29,362,126,415.00', 'R$ 5.00'))
# (('2016', '39_PLASTICS_AND_ARTICLES_THEREOF'), ('R$ 11,560,278,090.00', 'R$ 5.00'))
# (('2016', '40_RUBBER_AND_ARTICLES_THEREOF'), ('R$ 33,345,278,420.00', 'R$ 5.00'))
# (('2016', '41_RAW_HIDES_AND_SKINS_OTHER_THAN_FURSKINS_AND_LEATHER'), ('R$ 10,614,007,980.00', 'R$ 5.00'))
# (('2016', '42_ARTICLES_OF_LEATHER_ANIMAL_GUT_HARNESS_TRAVEL_GOOD'), ('R$ 46,841,324,390.00', 'R$ 5.00'))
# (('2016', '43_FURSKINS_AND_ARTIFICIAL_FUR_MANUFACTURES_THEREOF'), ('R$ 14,521,275,665.00', 'R$ 5.00'))
# (('2016', '44_WOOD_AND_ARTICLES_OF_WOOD_WOOD_CHARCOAL'), ('R$ 37,641,145,820.00', 'R$ 5.00'))
# (('2016', '45_CORK_AND_ARTICLES_OF_CORK'), ('R$ 2,378,957,400.00', 'R$ 5.00'))
# (('2016', '46_MANUFACTURES_OF_PLAITING_MATERIAL_BASKETWORK_ETC'), ('R$ 4,436,524,645.00', 'R$ 10.00'))
# (('2016', '47_PULP_OF_WOOD_FIBROUS_CELLULOSIC_MATERIAL_WASTE_ETC'), ('R$ 25,644,436,435.00', 'R$ 5.00'))
# (('2016', '48_PAPER_PAPERBOARD_ARTICLES_OF_PULP_PAPER_AND_BOARD'), ('R$ 8,315,550,935.00', 'R$ 5.00'))
# (('2016', '49_PRINTED_BOOKS_NEWSPAPERS_PICTURES_ETC'), ('R$ 6,947,314,905.00', 'R$ 5.00'))
# (('2016', '50_SILK'), ('R$ 2,989,590,295.00', 'R$ 5.00'))
# (('2016', '51_WOOL_ANIMAL_HAIR_HORSEHAIR_YARN_AND_FABRIC_THEREOF'), ('R$ 10,647,404,950.00', 'R$ 5.00'))
# (('2016', '52_COTTON'), ('R$ 10,718,721,225.00', 'R$ 5.00'))
# (('2016', '53_VEGETABLE_TEXTILE_FIBRES_NES_PAPER_YARN_WOVEN_FABRI'), ('R$ 1,816,984,005.00', 'R$ 5.00'))
# (('2016', '54_MANMADE_FILAMENTS'), ('R$ 25,306,906,385.00', 'R$ 5.00'))
# (('2016', '55_MANMADE_STAPLE_FIBRES'), ('R$ 5,409,444,225.00', 'R$ 5.00'))
# (('2016', '56_WADDING_FELT_NONWOVENS_YARNS_TWINE_CORDAGE_ETC'), ('R$ 12,779,875,245.00', 'R$ 5.00'))
# (('2016', '57_CARPETS_AND_OTHER_TEXTILE_FLOOR_COVERINGS'), ('R$ 4,949,014,585.00', 'R$ 5.00'))
# (('2016', '58_SPECIAL_WOVEN_OR_TUFTED_FABRIC_LACE_TAPESTRY_ETC'), ('R$ 3,349,540,780.00', 'R$ 5.00'))
# (('2016', '59_IMPREGNATED_COATED_OR_LAMINATED_TEXTILE_FABRIC'), ('R$ 10,083,630,785.00', 'R$ 5.00'))
# (('2016', '60_KNITTED_OR_CROCHETED_FABRIC'), ('R$ 27,694,608,555.00', 'R$ 5.00'))
# (('2016', '61_ARTICLES_OF_APPAREL_ACCESSORIES_KNIT_OR_CROCHET'), ('R$ 5,291,622,735.00', 'R$ 5.00'))
# (('2016', '62_ARTICLES_OF_APPAREL_ACCESSORIES_NOT_KNIT_OR_CROCHET'), ('R$ 2,759,115,265.00', 'R$ 15.00'))
# (('2016', '63_OTHER_MADE_TEXTILE_ARTICLES_SETS_WORN_CLOTHING_ETC'), ('R$ 22,047,077,045.00', 'R$ 10.00'))
# (('2016', '64_FOOTWEAR_GAITERS_AND_THE_LIKE_PARTS_THEREOF'), ('R$ 85,263,145,855.00', 'R$ 10.00'))
# (('2016', '65_HEADGEAR_AND_PARTS_THEREOF'), ('R$ 13,422,626,950.00', 'R$ 5.00'))
# (('2016', '66_UMBRELLAS_WALKING_STICKS_SEAT_STICKS_WHIPS_ETC'), ('R$ 4,815,797,365.00', 'R$ 10.00'))
# (('2016', '67_BIRD_SKIN_FEATHERS_ARTIFICIAL_FLOWERS_HUMAN_HAIR'), ('R$ 6,188,238,415.00', 'R$ 5.00'))
# (('2016', '68_STONE_PLASTER_CEMENT_ASBESTOS_MICA_ETC_ARTICLES'), ('R$ 16,094,861,450.00', 'R$ 5.00'))
# (('2016', '69_CERAMIC_PRODUCTS'), ('R$ 24,427,255,980.00', 'R$ 5.00'))
# (('2016', '70_GLASS_AND_GLASSWARE'), ('R$ 7,742,278,205.00', 'R$ 5.00'))
# (('2016', '71_PEARLS_PRECIOUS_STONES_METALS_COINS_ETC'), ('R$ 303,007,851,560.00', 'R$ 5.00'))
# (('2016', '72_IRON_AND_STEEL'), ('R$ 8,571,848,245.00', 'R$ 5.00'))
# (('2016', '73_ARTICLES_OF_IRON_OR_STEEL'), ('R$ 6,135,912,180.00', 'R$ 5.00'))
# (('2016', '74_COPPER_AND_ARTICLES_THEREOF'), ('R$ 89,156,415,675.00', 'R$ 5.00'))
# (('2016', '75_NICKEL_AND_ARTICLES_THEREOF'), ('R$ 17,182,002,515.00', 'R$ 5.00'))
# (('2016', '76_ALUMINIUM_AND_ARTICLES_THEREOF'), ('R$ 22,451,836,445.00', 'R$ 5.00'))
# (('2016', '78_LEAD_AND_ARTICLES_THEREOF'), ('R$ 4,076,302,745.00', 'R$ 5.00'))
# (('2016', '79_ZINC_AND_ARTICLES_THEREOF'), ('R$ 4,538,917,615.00', 'R$ 5.00'))
# (('2016', '80_TIN_AND_ARTICLES_THEREOF'), ('R$ 5,599,360,440.00', 'R$ 5.00'))
# (('2016', '81_OTHER_BASE_METALS_CERMETS_ARTICLES_THEREOF'), ('R$ 7,167,635,605.00', 'R$ 5.00'))
# (('2016', '82_TOOLS_IMPLEMENTS_CUTLERY_ETC_OF_BASE_METAL'), ('R$ 4,553,937,775.00', 'R$ 10.00'))
# (('2016', '83_MISCELLANEOUS_ARTICLES_OF_BASE_METAL'), ('R$ 11,015,181,285.00', 'R$ 5.00'))
# (('2016', '84_NUCLEAR_REACTORS_BOILERS_MACHINERY_ETC'), ('R$ 15,161,794,530.00', 'R$ 5.00'))
# (('2016', '85_ELECTRICAL_ELECTRONIC_EQUIPMENT'), ('R$ 18,666,375,795.00', 'R$ 5.00'))
# (('2016', '86_RAILWAY_TRAMWAY_LOCOMOTIVES_ROLLING_STOCK_EQUIPMEN'), ('R$ 21,142,785,275.00', 'R$ 5.00'))
# (('2016', '87_VEHICLES_OTHER_THAN_RAILWAY_TRAMWAY'), ('R$ 177,222,391,180.00', 'R$ 20.00'))
# (('2016', '88_AIRCRAFT_SPACECRAFT_AND_PARTS_THEREOF'), ('R$ 211,552,692,360.00', 'R$ 15.00'))
# (('2016', '89_SHIPS_BOATS_AND_OTHER_FLOATING_STRUCTURES'), ('R$ 81,556,499,785.00', 'R$ 15.00'))
# (('2016', '90_OPTICAL_PHOTO_TECHNICAL_MEDICAL_ETC_APPARATUS'), ('R$ 16,682,198,850.00', 'R$ 5.00'))
# (('2016', '91_CLOCKS_AND_WATCHES_AND_PARTS_THEREOF'), ('R$ 17,889,293,210.00', 'R$ 5.00'))
# (('2016', '92_MUSICAL_INSTRUMENTS_PARTS_AND_ACCESSORIES'), ('R$ 1,788,879,335.00', 'R$ 5.00'))
# (('2016', '93_ARMS_AND_AMMUNITION_PARTS_AND_ACCESSORIES_THEREOF'), ('R$ 19,269,948,215.00', 'R$ 5.00'))
# (('2016', '94_FURNITURE_LIGHTING_SIGNS_PREFABRICATED_BUILDINGS'), ('R$ 83,220,936,435.00', 'R$ 20.00'))
# (('2016', '95_TOYS_GAMES_SPORTS_REQUISITES'), ('R$ 91,912,801,985.00', 'R$ 5.00'))
# (('2016', '96_MISCELLANEOUS_MANUFACTURED_ARTICLES'), ('R$ 10,010,472,290.00', 'R$ 5.00'))
# (('2016', '97_WORKS_OF_ART_COLLECTORS_PIECES_AND_ANTIQUES'), ('R$ 40,572,052,610.00', 'R$ 5.00'))
# (('2016', '99_COMMODITIES_NOT_SPECIFIED_ACCORDING_TO_KIND'), ('R$ 814,667,207,600.00', 'R$ 5.00'))
# (('2016', 'ALL_COMMODITIES'), ('R$ 11,248,304,452,160.00', 'R$ 9,040.00'))

# %%
# 9 - Retornar um único valor para PairRDD contendo o país com a maior exportação (Flow=Export):
# Filtrar o RDD para transações de exportação e garantir que o preço é numérico
export_rdd = rdd.filter(lambda line: len(line.split(";")) > 5 and line.split(";")[4] == "Export" and line.split(";")[5].replace('.', '', 1).isdigit())

# Mapear para (chave, valor) onde chave = (país, flow) e valor = preço convertido para float
export_pair_rdd = export_rdd.map(lambda line: (line.split(";")[0], float(line.split(";")[5])))

# Somar os preços de exportação por país
export_total_per_country = export_pair_rdd.reduceByKey(lambda x, y: x + y)

# Encontrar o país com a maior exportação
country_with_max_export = export_total_per_country.takeOrdered(1, key=lambda x: -x[1])[0]  # Ordena e pega o maior valor

# Formatando a saída final para mostrar como esperado
resultado = ((country_with_max_export[0], "Export"), f"R$ {country_with_max_export[1] * 5.0:,.2f}")  # Convertendo para BRL e formatando
print(resultado)
# Out:
# (('EU-28', 'Export'), 'R$ 185,677,734,421,835.00')

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row

# Inicializar SparkSession (necessário para usar SparkSQL)
spark = SparkSession.builder.appName("TDE3").getOrCreate()

# %%
# 10 - Retornar o preço máximo por país e por ano utilizando as funções do SparkSQL:
# Transformar RDD em DataFrame
# Separar as colunas e garantir que ano e preço são numéricos
data_rows = rdd.map(lambda line: line.split(";")) \
               .filter(lambda fields: len(fields) > 5 and fields[1].isdigit() and fields[5].replace('.', '', 1).isdigit()) \
               .map(lambda fields: Row(country=fields[0], year=int(fields[1]), price=float(fields[5])))

# Criar DataFrame a partir do RDD
df = spark.createDataFrame(data_rows)

# Registrar o DataFrame como uma tabela temporária
df.createOrReplaceTempView("transactions")

# Executar consulta SQL para encontrar o preço máximo por país e ano
query = """
SELECT country, year, MAX(price) AS max_price
FROM transactions
GROUP BY country, year
ORDER BY country, year
"""

max_price_by_country_and_year = spark.sql(query)

# Exibir o resultado formatado, convertendo os preços para reais
conversion_rate = 5.0  # Exemplo: 1 USD = 5 BRL
result = max_price_by_country_and_year.withColumn("max_price_brl", max_price_by_country_and_year["max_price"] * conversion_rate) \
                                      .select("country", "year", "max_price_brl")

# Mostrar os resultados
result.show(truncate=False)
# Out:
# +-----------+----+---------------+
# |country    |year|max_price_brl  |
# +-----------+----+---------------+
# |Afghanistan|2008|1.5099300645E10|
# |Afghanistan|2009|1.6682173905E10|
# |Afghanistan|2010|2.5771249335E10|
# |Afghanistan|2011|3.1951554735E10|
# |Afghanistan|2012|3.1024920505E10|
# |Afghanistan|2013|4.2772068745E10|
# |Afghanistan|2014|3.848589085E10 |
# |Afghanistan|2015|3.8614325245E10|
# |Afghanistan|2016|3.2670702065E10|
# |Albania    |1996|4.69240896E9   |
# |Albania    |1997|3.14513152E9   |
# |Albania    |1998|4.20628092E9   |
# |Albania    |1999|5.771755845E9  |
# |Albania    |2000|5.447339395E9  |
# |Albania    |2001|6.65315533E9   |
# |Albania    |2002|7.51842603E9   |
# |Albania    |2003|9.3216443E9    |
# |Albania    |2004|1.1500841705E10|
# |Albania    |2005|1.307173506E10 |
# |Albania    |2006|1.528704213E10 |
# +-----------+----+---------------+
# only showing top 20 rows

# %%
# 11 - Buscar o preço mínimo por país e por ano, filtrado de forma crescente por ano e país (ordem alfabética):
# Definir a taxa de conversão de USD para BRL
conversion_rate = 5.0  # Exemplo: 1 USD = 5 BRL

# Transformar RDD em DataFrame
data_rows = rdd.map(lambda line: line.split(";")) \
               .filter(lambda fields: len(fields) > 5 and fields[1].isdigit() and fields[5].replace('.', '', 1).isdigit()) \
               .map(lambda fields: Row(country=fields[0], year=int(fields[1]), price=float(fields[5])))

# Criar DataFrame a partir do RDD
df = spark.createDataFrame(data_rows)

# Registrar o DataFrame como uma tabela temporária
df.createOrReplaceTempView("transactions")

# Executar consulta SQL para encontrar o preço mínimo por país e ano
query = """
SELECT country, year, MIN(price) AS min_price
FROM transactions
GROUP BY country, year
ORDER BY year ASC, country ASC
"""

min_price_by_country_and_year = spark.sql(query)

# Converter o preço mínimo para reais e formatar
min_price_in_brl = min_price_by_country_and_year.withColumn("min_price_brl", min_price_by_country_and_year["min_price"] * conversion_rate) \
                                                .select("country", "year", "min_price_brl")

# Exibir o resultado
min_price_in_brl.show(truncate=False)
# Out:
# +------------------------+----+-------------+
# |country                 |year|min_price_brl|
# +------------------------+----+-------------+
# |Australia               |1988|35.0         |
# |Finland                 |1988|10.0         |
# |Fmr Fed. Rep. of Germany|1988|5000.0       |
# |Greece                  |1988|10.0         |
# |Haiti                   |1988|505.0        |
# |Iceland                 |1988|40.0         |
# |India                   |1988|30.0         |
# |Japan                   |1988|8035.0       |
# |Portugal                |1988|25.0         |
# |Rep. of Korea           |1988|5.0          |
# |Switzerland             |1988|35.0         |
# |Thailand                |1988|20.0         |
# |Australia               |1989|5.0          |
# |Bangladesh              |1989|5.0          |
# |Brazil                  |1989|5.0          |
# |Canada                  |1989|20.0         |
# |Cyprus                  |1989|10.0         |
# |Denmark                 |1989|475.0        |
# |Finland                 |1989|35.0         |
# |Fmr Fed. Rep. of Germany|1989|5000.0       |
# +------------------------+----+-------------+
# only showing top 20 rows

# %%
# 12 - Transação que teve o maior preço por kg do tipo export. Buscar essa informação e indicar em qual ano, país e categoria, ela aconteceu:
# Definir a taxa de conversão de USD para BRL
conversion_rate = 5.0  # Exemplo: 1 USD = 5 BRL

# Transformar o RDD em DataFrame e garantir que os campos necessários são válidos
data_rows = rdd.map(lambda line: line.split(";")) \
               .filter(lambda fields: len(fields) > 7 and fields[4] == "Export" and
                       fields[5].replace('.', '', 1).isdigit() and
                       fields[6].replace('.', '', 1).isdigit()) \
               .map(lambda fields: Row(country=fields[0], year=int(fields[1]), category=fields[9],
                                       price=float(fields[5]), weight=float(fields[6])))

# Criar DataFrame a partir do RDD
df = spark.createDataFrame(data_rows)

# Registrar o DataFrame como uma tabela temporária
df.createOrReplaceTempView("transactions")

# Executar consulta SQL para calcular o preço por kg e encontrar o valor máximo para exportações
query = f"""
SELECT country, year, category, (price / weight) * {conversion_rate} AS price_per_kg_brl
FROM transactions
WHERE weight > 0
ORDER BY price_per_kg_brl DESC
LIMIT 1
"""

max_price_per_kg_export = spark.sql(query)

# Exibir o resultado
max_price_per_kg_export.show(truncate=False)
# Out:
# +-------+----+--------------------------------------------+----------------+
# |country|year|category                                    |price_per_kg_brl|
# +-------+----+--------------------------------------------+----------------+
# |Norway |1999|89_ships_boats_and_other_floating_structures|1.463344E9      |
# +-------+----+--------------------------------------------+----------------+
